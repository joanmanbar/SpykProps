# %% [markdown]
# # Execute SpykProps on a folder with images

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# cd '/content/drive/MyDrive/M.Sc/THESIS/ImageAnalysis/SpikeProperties/Spyk_Prop'

# %%
# pip install skan

# %%
# import sys
# sys.path.append('/content/drive/MyDrive/M.Sc/THESIS/ImageAnalysis/SpikeProperties/Spyk_Prop')
# sys.path

# %%
from SpykFunctions import *
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 600

# Make sure Jupyter Notebook shows all outputs from the same cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Define the function

# %%
def SpykBatch(Images, TROE2020=False):
    
    import time
    from datetime import datetime, date
    start_time = time.time()    
    Nimages = str(len(Images)) 
    Spikes_data = pd.DataFrame()
    Contours_data = pd.DataFrame()
    Spklts_data = pd.DataFrame()
    Distances_data = pd.DataFrame()   
    Counter=0

    for img_name in Images:
        
        try:

            Counter = Counter+1
            Progress = str(Counter) + "/" + Nimages
            # img_name=Images[0]
            now = datetime.now().strftime("%H:%M:%S")
            print("Processing image " + Progress + ": ", img_name + " at " + now)
            # img_name = Images[9]

            # Set the initial time per image
            image_time = time.time()

            # Remove background and create images
            I = RemoveBackground(img_name, OtsuScaling=0.25, 
                                 rgb_out=True, gray_out=True, 
                                 lab_out=True, hsv_out=True, 
                                 bw_out=True)
            rgb0 = I[0]
            gray0 = I[1]
            lab0 = I[2]
            hsv0 = I[3]
            bw0 = I[4]

            # Enumerate spikes
        #     EnumerateSpkCV(bw0, rgb0, TextSize=5, TROE2020=False)

            # Collect spikes data
            df = SpikesDF(I=I, ImagePath=img_name, RemoveBG=False, rm_envelope=False)

            # Label spikes
            labeled_spks, num_spikes = label(bw0, return_num = True)
            # plt.imshow(labeled_spks==1)

            # Spike lengths
            SpkLengths = []

            # Spike distances from each other
            SpkDists = []

            # TROE2021 and PGR start at 2. Ignore background (0) and envelope (1)
            # if TROE2020==False:
            #     FirstSpk = 2
            # else:
            #     FirstSpk = 1

            ContoursPerSpk = pd.DataFrame()
            SpkltsPerSpk = pd.DataFrame()
            DistancesPerSpk = pd.DataFrame()    

            # Start at 1 so it ignores background (0) 
            for Label in range(1, num_spikes+1):
                
                try:
                    print("Processing spike ", Label)
            #         plt.imshow(labeled_spks==2)

                    spk = labeled_spks==Label
                    # io.imshow(spk)

                    # Crop spike
                    slice_x, slice_y = ndimage.find_objects(spk)[0]
                    cropped_spk = spk[slice_x, slice_y]
                    cropped_rgb = rgb0[slice_x, slice_y]
                    cropped_rgb = np.where(cropped_spk[..., None], cropped_rgb, 0)
                    cropped_gray = color.rgb2gray(cropped_rgb)
                    cropped_lab = color.rgb2lab(cropped_rgb)
                    cropped_hsv = color.rgb2hsv(cropped_rgb)
            #         io.imshow(cropped_spk)

                    # Spike length
                    sl = spk_length(cropped_spk, Overlay=False)
                    SpkLengths.append(sl)

                    # Theshold for detection
                    thresh2 = SpkltThresh(cropped_rgb, ResizeFactor=30, thr2=0.8, MinSize=1000)
                    # plt.imshow(thresh2)

                    # Distances between contours
                    D = DistAll(bw=thresh2, HeatMap=False, spike_length=sl)
                    SpkDists.append(D)
                    # Image_Name = [img_name.split('\\')[-1]]
                    # DistMat = pd.DataFrame(list(zip(Image_Name, str(Label), D)), columns = ['Image_Name', 'Spike_Label', 'MatrixD'])

                    # Contours
                    labels_cont = CountorProps(cropped_rgb, cropped_lab, cropped_hsv, thresh2, 
                                               ImagePath=img_name, ResizeFactor=30, MinSize = 1000, 
                                               thr2=0.8, Plot=False)
                    # Add spike label
                    labels_cont['Spike_Label'] = [str(Label)] * len(labels_cont)

                    # Watershed segments
                    spklts, n_spklts= LabelSpklts(cropped_rgb, MinDist=50, labels_out=True, n_spklt=True, Plot=False)
                    WSProps = ObjProps(labeled=spklts, cropped_rgb=cropped_rgb, cropped_lab=cropped_lab, cropped_hsv=cropped_hsv, ImagePath=img_name, MinSize = 5000)
                    # Add spike label
                    WSProps['Spike_Label'] = [str(Label)] * len(WSProps)

                    ContoursPerSpk = ContoursPerSpk.append(labels_cont)
                    SpkltsPerSpk = SpkltsPerSpk.append(WSProps)
                   
                    # DistancesPerSpk = DistancesPerSpk.append(DistMat)
                    
                except:
                    print('there was an error!')
                    pass

            Contours_data = Contours_data.append(ContoursPerSpk)
            Spklts_data = Spklts_data.append(SpkltsPerSpk)
            # Distances_data = Distances_data.append(SpkDists)

            # Add spike lengths and append current data frame
            df["SpykLength"] = SpkLengths
            Spikes_data = Spikes_data.append(df)

            # Distances matrix

            # Create columns with image name, spike index, and distances matrix
            Image_Name = img_name.split('\\')[-1]
            Image_Name = [Image_Name] * len(SpkDists)
            Spk_Index = [number for number in range(1, num_spikes+1)]
            # Matrix of distances among detected spikelets
            DistMat = pd.DataFrame(list(zip(Image_Name, Spk_Index, SpkDists)), columns = ['Image_Name', 'Spike_Label', 'MatrixD'])
            # Append
            Distances_data = Distances_data.append(DistMat)

            # How long did it take to run this image?
            print("Image " + img_name.split('\\')[-1] + ", " + Progress + ", was fully processed in " + str(round(time.time() - image_time, 1)) + " seconds. " + "\n")
            
        except:
            print('there was an error!')
            pass

    # How long did it take to run the whole code?
    print("This entire code took", str(round(time.time() - start_time, 1)), "seconds to run.")

    return Spikes_data, Contours_data, Spklts_data, Distances_data

# %%
def SpykBatch(Images,channel_thresh=None,SpikeletData=True,EucDist=True,
              QC_spike=True,QC_spikelet=True,rescale_rgb=None,MinDist=50,headless=True):
    
    from SpykFunctions import *
    
    if headless == True:
        VerifySettings = 'n'
        while VerifySettings != 'y' or VerifySettings != 'Y':
            print("Enter the following information or type 'cancel' \n\n")
            # Path and format
            path = input("Images' folder: \n")
            if path == 'cancel':
                sys.exit()
            img_format = input("Images's format, or PRESS RETURN to select '.tif' \n")
            if img_format == '':
                img_format = '.tif'
            elif img_format == 'cancel':
                sys.exit()
            Images = ListImages(path, imgformat=img_format, recursive=False)
            # Resize image
            rescale_rgb = input("Rescale images by factor? \nE.g. '0.5' resizes by half in each image axis. \nOtherwise PRESS RETURN to keep original size \n ")
            if rescale_rgb == '':
                rescale_rgb = None
            elif rescale_rgb == 'cancel':
                sys.exit()
            # Spike segmentation method
            channel_thresh = input("Channel and threshold for spike segmentation. \nE.g. '[0,30]' thresholds on channel 0 and above 30. \nOtherwise PRESS RETURN to select 'Otsu Segmentation' \n")
            if channel_thresh == '':
                channel_thresh = None
                toprint = 'Otsu by 0.25'
            elif channel_thresh == 'cancel':
                sys.exit()
            # Spikelets minimum distance
            MinDist = input("Minimum distance (in pixels) between spikelets? \nSuggested: \n    50 for original size \n    40 for images rescaled at 0.75 or 0.5 \n")
            if MinDist == 'cancel':
                sys.exit()
                
            print("\n*********************************\n\nSettings: \n",
                  " headless = True",
                  "\n  Images' folder: ", path,
                 "\n  Images's format: ", img_format,
                 "\n  Rescale factor: ", rescale_rgb,
                 "\n  Method for spike segmentation: ", str(toprint),
                 "\n  Spikelets minimum distance: ", str(MinDist),
                 "\n\n*********************************\n")
            VerifySettings = input("Correct? (y/n): \n")
        
    print('\n\nReady to start analysis! \n')        
    
    import time
    from datetime import datetime, date
    start_time = time.time()    
    Nimages = str(len(Images)) 
    Spikes_data = pd.DataFrame()
    Spklts_data = pd.DataFrame()
    Distances_data = pd.DataFrame()   
    Counter=0
    # Define output folders
    OutFolder = Images[0].rsplit('/', 1)[0]
    OutFolder = OutFolder + '/' + datetime.now().strftime("%y%m%d_%H%M")    
    if QC_spike == True:
        SpikeFolder = OutFolder + '/SpikeSegm/'
        Path(SpikeFolder).mkdir(parents=True, exist_ok=True)       
    if QC_spikelet == True:
        SpikeletFolder = OutFolder + '/SpikeletSegm/'
        Path(SpikeletFolder).mkdir(parents=True, exist_ok=True)      
    if QC_length == True:
        LengthFolder = OutFolder + '/SpikeLength/'
        Path(LengthFolder).mkdir(parents=True, exist_ok=True) 
        

    for img_name in Images:        
        try:
            Image_Name = img_name.split('/')[-1]
            Counter = Counter+1
            Progress = str(Counter) + "/" + Nimages
            # img_name=Images[0]
            now = datetime.now().strftime("%H:%M:%S")
            print(now + " - Processing image " + Progress + ": ", img_name)
            # img_name = Images[9]
            # Set the initial time per image
            image_time = time.time()
            
            # Spike segmentation
            I = spike_segm(img_name, rescale_rgb=rescale_rgb, channel_thresh=channel_thresh, 
                           OtsuScaling=0.25, rgb_out=True, gray_out=True, lab_out=True, 
                           hsv_out=True, bw_out=True, crop_coord=[44,6940,25,4970])
            rgb0 = I[0]
            gray0 = I[1]
            lab0 = I[2]
            hsv0 = I[3]
            bw0 = I[4]            
            # Enumerate spikes (to check spike segmentation)
            if QC_spike == True:
                Enum_spike = EnumerateSpkCV(bw0, rgb0, TextSize=None, 
                                          Plot=False, PlotOut=True)
                Filename = SpikeFolder + Image_Name.replace('.tif','.jpg')
                im = Image.fromarray(Enum_spike)
                im.save(Filename)

            # Collect spikes data (doesn't include spike length)
            df = SpikesDF(I=I, ImagePath=img_name)

            # Label spikes
            labeled_spks, num_spikes = label(bw0, return_num = True)

            # Prepare empty lists and DFs
            SpkLengths = []    # Spike lengths
            SpkDists = []    # spikelet distances 
            SpkltsPerSpk = pd.DataFrame()    # Spikelets data
            DistancesPerSpk = pd.DataFrame()    # Spikelet distances data     

            # Start at 1 so it ignores background (0) 
            for Label in range(1, num_spikes+1):
                try:
                    print("Processing spike ", Label)
                    spk = labeled_spks==Label
                    # Crop spike
                    slice_x, slice_y = ndimage.find_objects(spk)[0]
                    cropped_spk = spk[slice_x, slice_y]
                    cropped_rgb = rgb0[slice_x, slice_y]
                    cropped_rgb = np.where(cropped_spk[..., None], cropped_rgb, 0)
                    cropped_gray = color.rgb2gray(cropped_rgb)
                    cropped_lab = color.rgb2lab(cropped_rgb)
                    cropped_hsv = color.rgb2hsv(cropped_rgb)

                    # Spike length 
                    if QC_length == True:
                        sl, length_img = spk_length(cropped_spk, Method='skel_ma',Overlay=True)
                        SpkLengths.append(sl)
                    else:
                        sl, length_img = spk_length(cropped_spk, Method='skel_ma',Overlay=True)
                        SpkLengths.append(sl)
                        Filename = LengthFolder + Image_Name.replace('.tif','.jpg')
                        im = Image.fromarray(length_img)
                        im.save(Filename)
                                           
                    # Spikelet segmentation
                    if QC_spikelet == True:
                        Spikelets,EllipseData,Spikelets_Image = spikelet_segm(
                            cropped_rgb=cropped_rgb,Pad=200,MinDist=MinDist,data_out=True,
                            plot_ellipse=True,Numbered=True,img_out=True,plot_segmented=False)
                        Filename = SpikeletFolder + Image_Name.replace('.tif','')
                        Filename = Filename + '_'+ str(Label) + '.jpg'
                        im = Image.fromarray(Spikelets_Image)
                        im.save(Filename)
                    else:
                        Spikelets,EllipseData = spikelet_segm(
                            cropped_rgb=cropped_rgb,Pad=200,MinDist=MinDist,data_out=True,
                            plot_ellipse=False,Numbered=False,img_out=False,plot_segmented=False)
                    
                    if SpikeletData==True:
                        SpikeletProps = SpikeletsDF(labeled=Spikelets,Pad=200,cropped_rgb=cropped_rgb, 
                                           cropped_lab=cropped_lab, cropped_hsv=cropped_hsv,
                                           ImagePath=img_name)
                        SpikeletProps = pd.concat([EllipseData,SpikeletProps], axis=1)
                    
                    # Distances between spikelets (ellipses' centroids)
                    if EucDist == True:
                        D = DistAll(EllipseData=EllipseData, HeatMap=False, spike_length=sl)
                        SpkDists.append(D)                    
                    
                    # Add spike label
                    SpikeletProps['Spike_Label'] = [str(Label)] * len(SpikeletProps)

                    # SpkltsPerSpk = SpkltsPerSpk.append(SpikeletProps)
                    SpkltsPerSpk = pd.concat([SpkltsPerSpk,SpikeletProps])
                                       
                except Exception as e:
                    print('There was an error with this spike:')
                    print(e)
                    pass

            # Spklts_data = Spklts_data.append(SpkltsPerSpk)
            Spklts_data = pd.concat([Spklts_data,SpkltsPerSpk])
            # Distances_data = Distances_data.append(SpkDists)

            # Add spike lengths and append current data frame
            df["SpykLength"] = SpkLengths
            # Spikes_data = Spikes_data.append(df)
            Spikes_data = pd.concat([Spikes_data,df])

            # Create columns with image name, spike index, and distances matrix
            Image_Name = [Image_Name] * len(SpkDists)
            Spk_Index = [number for number in range(1, num_spikes+1)]
            
            if EucDist == True:
                # Matrix of distances among detected spikelets
                DistMat = pd.DataFrame(list(zip(Image_Name, Spk_Index, SpkDists)), columns = ['Image_Name', 'Spike_Label', 'MatrixD'])
                # Append
                # Distances_data = Distances_data.append(DistMat)
                Distances_data = pd.concat([Distances_data,DistMat])

            # How long did it take to run this image?
            print("Image " + img_name.split('\\')[-1] + ", " + Progress + ", was fully processed in " + str(round(time.time() - image_time, 1)) + " seconds. " + "\n")
            
        except Exception as e:
            print('there was an error!')
            print(e)
            pass

    # How long did it take to rusn the whole code?
    print("Run time: ", 
          str(round(time.time() - start_time, 1)), "seconds", 
          "\nProcessed Images: ", len(Images),
          " \nProcessed spikes: ", len(Spikes_data), 
          "\nAll data was saved in ", OutFolder
         )
    # Export csv file
    if headless == True:
        Spikes_data.to_csv(OutFolder + "/Spikes_data.csv", index=False)
        Spklts_data.to_csv(OutFolder + "/Spikelets_data.csv", index=False)
        Distances_data.to_csv(OutFolder + "/EucDistances_data.csv", index=False)
    else:
        return Spikes_data, Spklts_data, Distances_data

# %%
im_075 = rescale(cropped_rgb[...], 0.75, preserve_range=False, channel_axis=2, anti_aliasing=True)
im_050 = rescale(cropped_rgb[...], 0.5, preserve_range=False, channel_axis=2, anti_aliasing=True)
im_040 = rescale(cropped_rgb[...], 0.4, preserve_range=False, channel_axis=2, anti_aliasing=True)
im_030 = rescale(cropped_rgb[...], 0.3, preserve_range=False, channel_axis=2, anti_aliasing=True)
im_020 = rescale(cropped_rgb[...], 0.2, preserve_range=False, channel_axis=2, anti_aliasing=True)
im_010 = rescale(cropped_rgb[...], 0.1, preserve_range=False, channel_axis=2, anti_aliasing=True)
im_075 = (im_075 * 255).astype(np.uint8)
im_050 = (im_050 * 255).astype(np.uint8)
im_040 = (im_040 * 255).astype(np.uint8)
im_030 = (im_030 * 255).astype(np.uint8)
im_020 = (im_020 * 255).astype(np.uint8)
im_010 = (im_010 * 255).astype(np.uint8)

cropped_rgb.shape
im_075.shape
im_050.shape
im_040.shape
im_030.shape
im_020.shape
im_010.shape
# Out:
# (901, 2536, 3)
# (676, 1902, 3)
# (450, 1268, 3)
# (360, 1014, 3)
# (270, 761, 3)
# (180, 507, 3)
# (90, 254, 3)

# %%
def spk_length(cropped_spk,Method='skel_ma',Overlay=True):

    cropped_spk = np.pad(cropped_spk, pad_width=[(100, 100),(100, 100)], mode='constant')
    
    Length_data = []
    Time_data = []
    
    # Bounding box 
    if Method == "all" or Method == "bbox":
        track_time = time.time() # Track time
        label_bbox = label(cropped_spk)
        bbox_MajorAxis_L = regionprops(label_bbox)
        bbox_MajorAxis_L  = round(bbox_MajorAxis_L[0]['major_axis_length'], 0)
        total_time = round(time.time() - track_time, 2) # Total time
        Length_data.append(bbox_MajorAxis_L)
        Time_data.append(total_time)
    
    # Convex hull
    if Method == "all" or Method == "chull":
        track_time = time.time() # Track time
        chull = convex_hull_image(cropped_spk)
        label_chull = label(chull)
        chull_MajorAxis_L = regionprops(label_chull)
        chull_MajorAxis_L  = round(chull_MajorAxis_L[0]['major_axis_length'], 0)
        total_time = round(time.time() - track_time, 2) # Total time        
        Length_data.append(chull_MajorAxis_L)
        Time_data.append(total_time)
    
    # Skeleton (Lee, 94)
    if Method == "all" or Method == "skel_ma":     
        track_time = time.time() # Track time
        # Severly blur the image
        blur = cv2.blur(np.float32(cropped_spk),(100,100))
        # Threshold the blur
        thrb = blur > 0.1
        skeleton_ma = medial_axis(thrb)
        # Spike length
        SpkL_ma = cv2.countNonZero(np.float32(skeleton_ma))
        total_time = round(time.time() - track_time, 2) # Total time        
        Length_data.append(SpkL_ma)
        Time_data.append(total_time)
        
    # Skeleton
    if Method == "all" or Method == "skel":     
        track_time = time.time() # Track time
        # Severly blur the image
        blur = cv2.blur(np.float32(cropped_spk),(100,100))
        # Threshold the blur
        thrb = blur > 0.1
        skeleton = skeletonize(thrb)
        # Spike length
        SpkL = cv2.countNonZero(np.float32(skeleton))
        total_time = round(time.time() - track_time, 2) # Total time        
        Length_data.append(SpkL)
        Time_data.append(total_time)

        
    # Visualize overlay?
    if Overlay == True and Method == 'skel_ma':
        # Dilate skeleton and color it
        dil_skel = ndimage.binary_dilation(skeleton_ma, np.ones((7,7)))
        rgb_skel = np.zeros((dil_skel.shape[0],dil_skel.shape[1],3), dtype=np.uint8)
        # Make True pixels red
        rgb_skel[dil_skel]  = [255,0,0]
        # Make False pixels blue
        rgb_skel[~dil_skel] = [0,0,0]
        # plt.imshow(rgb_skel)

        img_color = np.dstack((cropped_spk, cropped_spk, cropped_spk))
        img_hsv = color.rgb2hsv(img_color)
        color_mask_hsv = color.rgb2hsv(rgb_skel)
        img_hsv[..., 0] = color_mask_hsv[..., 0]
        img_hsv[..., 1] = color_mask_hsv[..., 1]
        img_masked = color.hsv2rgb(img_hsv)
        
        return Length_data[0], img_masked
        
    elif Overlay == False and Method == "all":
        Length_data = pd.DataFrame(Length_data).transpose()
        Length_data = Length_data.rename(
            columns={0:'bbox',1:'chull',2:'skel_Lee',3:'skel'})
        
        Time_data = pd.DataFrame(Time_data).transpose()
        Time_data = Time_data.rename(
            columns={0:'bbox',1:'chull',2:'skel_Lee',3:'skel'})
        
        return Length_data, Time_data
    else:
        return Length_data[0]

## Example:
# SL, length_img = spk_length(cropped_spk, Overlay=True)
# Lengths,Time = spk_length(cropped_spk, Method='all', Overlay=False)

# %% [markdown]
# ## Batch execution

# %%
# %%time

from SpykFunctions import *
# path = r'./Images/PGR_Roseau2021'
# path = r'./Images/TROE2021'
# path = r'./Images/PGR_GH2021'
# path = r'./Images/LaptopTest'
path = './Images/PGR_GH2021/Corrupted'
Images = ListImages(path, imgformat=".tif", recursive=False)

# Spikes_data,Spklts_data,Distances_data=SpykBatch(
#     Images,channel_thresh=[0,30],SpikeletData=True,EucDist=True,
#     QC_spike=True,QC_spikelet=True,
#     rescale_rgb=0.5,MinDist=40,headless=True)

# For GH (127/127 images): Wall time: 2h 54min 13s
# For Roseau (40/40 images): Wall time: 51min 13s
# Out:
# CPU times: total: 0 ns
# Wall time: 8.45 ms

# %% [markdown]
# ## Export datasets

# %% [markdown]
# ### PGR Roseau 2021

# %%
from datetime import datetime, date
Today = date.today().strftime("%Y%m%d")

Spikes_data.to_csv(".\Output\{}2021_SpikeData_{}.csv".format('Roseau',Today), index=False)
Contours_data.to_csv(".\Output\{}2021_ContoursData_{}.csv".format('Roseau',Today), index=False)
Spklts_data.to_csv(".\Output\{}2021_SpkltsData_{}.csv".format('Roseau',Today), index=False)
Distances_data.to_csv(".\Output\{}2021_DistancesData_{}.csv".format('Roseau',Today), index=False)

# %%
Spikes_data['Image_Name'].value_counts()
# p229P0109.tif     5
# p240P1821.tif     1

# %% [markdown]
# ### TROE 2021

# %%
Today = date.today().strftime("%Y%m%d")

Spikes_data.to_csv(".\Output\TROE2021_SpikeData_{}.csv".format(Today), index=False)
Contours_data.to_csv(".\Output\TROE2021_ContoursData_{}.csv".format(Today), index=False)
Spklts_data.to_csv(".\Output\TROE2021_SpkltsData_{}.csv".format(Today), index=False)
Distances_data.to_csv(".\Output\TROE2021_DistancesData_{}.csv".format(Today), index=False)

# %%
Spikes_data['Image_Name'].value_counts()
# p229P0109.tif     5
# p240P1821.tif     1

# %% [markdown]
# ### PGR GH2021

# %%
Today = date.today().strftime("%Y%m%d")

Spikes_data.to_csv(".\Output\PGRGH2021_SpikeData_{}.csv".format(Today), index=False)
Contours_data.to_csv(".\Output\PGRGH2021_ContoursData_{}.csv".format(Today), index=False)
Spklts_data.to_csv(".\Output\PGRGH2021_SpkltsData_{}.csv".format(Today), index=False)
Distances_data.to_csv(".\Output\PGRGH2021_DistancesData_{}.csv".format(Today), index=False)

# %%
Spikes_data['Image_Name'].value_counts()
# p229P0109.tif     5
# p240P1821.tif     1

# %% [markdown]
# ### Laptopr Test

# %%
from datetime import datetime, date
Today = date.today().strftime("%Y%m%d")

Spikes_data.to_csv(".\Output\{}_SpikeData_{}.csv".format('LaptopTest',Today), index=False)
Contours_data.to_csv(".\Output\{}_ContoursData_{}.csv".format('LaptopTest',Today), index=False)
Spklts_data.to_csv(".\Output\{}_SpkltsData_{}.csv".format('LaptopTest',Today), index=False)
Distances_data.to_csv(".\Output\{}_DistancesData_{}.csv".format('LaptopTest',Today), index=False)

# %%
# Images to re-analyze (lower Otsu coefficient) or discard from TROE 2021 
# p080P2527.tif.jpg
# p081P05--.tif.jpg
# p084P0903.tif.jpg

# %%
# %%time

from SpykFunctions import *

path = r'./Images/TROE2021'
Images= ListImages(path, imgformat=".tif", recursive=False)

# ./Images/PGR_Roseau2021\S2p03T2R1.tif

Spikes_data, Contours_data, Spklts_data, Distances_data = SpykBatch([Images[39]], TROE2020=False)

# %% [markdown]
# # Detect fake spikes

# %%
# %%time

from SpykFunctions import *

path = r'./Images/TROE2021'
Images = ListImages(path, imgformat=".tif", recursive=False)

img = Images[3]

# %%
# %%time

img_name = './Images/PGR_Roseau2021\\S1p20T2R4.tif'
# plt.imshow(plt.imread(img_name))

# Remove background and create images
I = RemoveBackground(img_name, OtsuScaling=0.25, rgb_out=True, gray_out=False, lab_out=False, hsv_out=False, bw_out=True)
rgb0 = I[0]
bw0 = I[1]
# gray0 = I[1]
# lab0 = I[2]
# hsv0 = I[3]
# bw0 = I[4]

plt.rcParams['figure.dpi'] = 300

# Enumerate spikes
EnumerateSpkCV(bw0, rgb0, TextSize=5, TROE2020=False)

# %%
## Fake spikes
S1p08T3R2.tif = 21, 23
S1p10T4R2.tif = 22
S1p12T3R3.tif = 19, 21

# %% [markdown]
# # Enumerate all images

# %%
def EnumBatch(Images, TROE2020=False, TextSize=3, OtsuScaling=0.25):
    
    import time
    start_time = time.time()
    
    Nimages = str(len(Images))
    Counter=0
    
    for img_name in Images:

        Counter = Counter+1
        Progress = str(Counter) + "/" + Nimages
        # img_name=Images[0]
        print("Enumerating image " + Progress + ": ", img_name)

        # Set the initial time per image
        image_time = time.time()

        # Remove background and create images
        I = RemoveBackground(img_name, OtsuScaling=OtsuScaling, rgb_out=True, gray_out=False, lab_out=False, hsv_out=False, bw_out=True)
        rgb0 = I[0]
        bw0 = I[1]

        EnumPlot = EnumerateSpkCV(bw0, rgb0, TextSize=TextSize, TROE2020=False, Plot=False, PlotOut=True)
        ThisImage = img_name.split('/')[-1:]
        plotname = '.\Images\ENUMERATED\\' + ThisImage[0] + '.jpg'
        plt.imsave(plotname, EnumPlot)           

        # How long did it take to run this image?
        print("Image " + img_name.split('\\')[-1] + ", " + Progress + ", was enumerated in " + str(round(time.time() - image_time, 1)) + " seconds." + "\n")
            
            
    # How long did it take to run the whole code?
    print("This entire code took", str(round(time.time() - start_time, 1)), "seconds to run.")

# %% [markdown]
# ## Enumerate PGR Roseau2021

# %%
# %%time
path = r'./Images/PGR_Roseau2021'
Images = ListImages(path, imgformat=".tif", recursive=False)

EnumBatch(Images, TROE2020=False, TextSize=3)
# Finished in about 4min (236.7 sec)

# %% [markdown]
# ## Enumerate TROE2021

# %%
# %%time
path = r'./Images/TROE2021'
Images = ListImages(path, imgformat=".tif", recursive=False)

EnumBatch(Images, TROE2020=False, TextSize=3)
# Finished in over 2h and 7min  ( 7638.1 sec)

# %% [markdown]
# ## Enumerate PGR GH2021

# %%
# %%time
path = r'./Images/PGR_GH2021'
Images = ListImages(path, imgformat=".tif", recursive=False)
EnumBatch(Images, TROE2020=False, TextSize=3, OtsuScaling=0.25)

# %% [markdown]
# ## Enumerate Validation images

# %%
# %%time
path = r'./Images/Validation'
Images = ListImages(path, imgformat=".tif", recursive=False)
EnumBatch(Images, TROE2020=False, TextSize=3, OtsuScaling=0.25)
# This entire code took 58.1 seconds to run.

# %% [markdown]
# # Gifs
# Gifs for presentations

# %%
# pip install imutils

# %%
from SpykFunctions import *
path = r'./Images/PGR_Roseau2021'
Images = ListImages(path, imgformat=".tif", recursive=False)
# img = Images['S1p14T4R3.tif']
img = [s for s in Images if "S1p15T5R3" in s]
img = img[0]

# %% [markdown]
# ## Remove Background

# %%
# %%time

# Remove Backgrouns
OtsuScaling=0.25
rgb_out=True
gray_out=True
lab_out=True
hsv_out=True

img0 = plt.imread(img)


# Crop images. They were all taken with the same scanner
img1 = img0[44:6940, 25:4970, :]

plt.imsave('.\GIFS\CSSA\Spikes\\01_RGBoriginal.jpg',img1)

 # Convert to gray
gray0 = img1 @ [0.2126, 0.7152, 0.0722]

plt.imsave('.\GIFS\CSSA\Spikes\\02_GRAYoriginal.jpg',gray0, cmap='gray')

# Set image threshold
T = filters.threshold_otsu(gray0)
#     print(T)
T = T*OtsuScaling
#     print(T)

# Segment gray image
bw0 = gray0 > T

plt.imsave('.\GIFS\CSSA\Spikes\\03_BWoriginal.jpg', bw0, cmap='gray')

# Remove small objects
n_pixels = gray0.shape[0] * gray0.shape[1]
minimum_size = n_pixels/10000
bw1 = morphology.remove_small_objects(bw0, min_size=np.floor(minimum_size))

plt.imsave('.\GIFS\CSSA\Spikes\\04_BW1original.jpg', bw1, cmap='gray')


if rgb_out==True:
    # Apply mask to RGB
    rgb = np.where(bw1[..., None], img1, 0)
    plt.imsave('.\GIFS\CSSA\Spikes\\05_ThreshRGB.jpg', rgb)
if gray_out==True and rgb_out==True:
    gray = color.rgb2gray(rgb)
    plt.imsave('.\GIFS\CSSA\Spikes\\06_ThreshGRAY.jpg', gray, cmap='gray')
# if lab_out==True and rgb_out==True:
    # lab = color.rgb2lab(rgb)
    # plt.imsave('.\GIFS\CSSA\Spikes\\07_ThreshLAB.jpg', lab)
if hsv_out==True and rgb_out==True:
    hsv = color.rgb2hsv(rgb)
    plt.imsave('.\GIFS\CSSA\Spikes\\08_ThreshHSV.jpg', hsv)

# %% [markdown]
# ## Enumerate

# %%
# %%time

TextSize = 5
nb_components, output, stats, centroids = cv2.connectedComponentsWithStats(np.uint8(bw1), connectivity=8)
img = rgb.copy()

counter=0
for c in centroids:
#         print(c)
    cx = round(c[0])
    cy = round(c[1])
    img = cv2.circle(img, (cx, cy), 10, (255, 0, 0), -1)
    img = cv2.putText(img, str(counter), (cx - 25, cy - 25),cv2.FONT_HERSHEY_SIMPLEX, TextSize, (255, 0, 0), 15)
    counter = counter+1

    if len(str(counter)) < 2:
        thisContour = '0' + str(counter)
    else:
        thisContour = str(counter)
    plotname = '.\GIFS\CSSA\Spikes\\09_enumerate_' + thisContour + '.jpg'
    plt.imsave(plotname, img)
    # plt.imshow(img)

# %%
# %%time
# EnumPlot = EnumerateSpkCV(bw1, rgb, TextSize=5, TROE2020=False, Plot=False, PlotOut=True)
# plotname = '.\GIFS\CSSA\Spikes\\10_enumerate_' + thisContour + '.jpg'
# plt.imsave(plotname, img)

# %% [markdown]
# ## Select a spike

# %%
# %%time

# Label spikes
labeled_spks, num_spikes = label(bw1, return_num = True)
# plt.imshow(labeled_spks==1)

Label = 8

spk = labeled_spks==Label
# plt.imshow(spk, cmap='gray')
plotname = '.\GIFS\CSSA\Spikes\\10_SelectedSpike_' + str(Label) + '.jpg'
plt.imsave(plotname, spk, cmap='gray')

# Crop spike
slice_x, slice_y = ndimage.find_objects(spk)[0]
cropped_spk = spk[slice_x, slice_y]
cropped_rgb = rgb[slice_x, slice_y]
cropped_rgb = np.where(cropped_spk[..., None], cropped_rgb, 0)
cropped_gray = color.rgb2gray(cropped_rgb)
cropped_lab = color.rgb2lab(cropped_rgb)
cropped_hsv = color.rgb2hsv(cropped_rgb)

plotname = '.\GIFS\CSSA\Spike\\01_rgb.jpg'
plt.imsave(plotname, cropped_rgb)
plotname = '.\GIFS\CSSA\Spike\\02_gray.jpg'
plt.imsave(plotname, cropped_gray, cmap='gray')
# plotname = '.\GIFS\CSSA\Spike\\03_lab.jpg'
# plt.imsave(plotname, cropped_lab)
plotname = '.\GIFS\CSSA\Spike\\04_hsv.jpg'
plt.imsave(plotname, cropped_hsv)
plotname = '.\GIFS\CSSA\Spike\\05_bw.jpg'
plt.imsave(plotname, cropped_spk, cmap='gray')

# %% [markdown]
# ## Spike Length

# %%
# %%time
def spk_length(cropped_spk, method='skelblur', Overlay=True, PlotCH=False, PlotOut=False):
    
    if method=='skelblur':
        # Severly blur the image
        blur = cv2.blur(np.float32(cropped_spk),(100,100))
        # Threshold the blur
        thrb = blur > 0.1
        skeleton = skeletonize(thrb)
#         plt.imshow(skeleton)
        
    if method=='chull':
        # Blur the image with a 50x50 kernel
        blur = cv2.blur(np.float32(cropped_spk),(50,50))

        # Get convex hull 
        chull = convex_hull_image(blur>0)

        # Perform skeletonization
        image = chull
        skeleton = skeletonize(image)
    #     plt.imshow(skeleton)
    
    # Spike length
    SpkL = cv2.countNonZero(np.float32(skeleton))
    
    if PlotCH == True:
        fig, axes = plt.subplots(1, 2, figsize=(8, 4))
        ax = axes.ravel()

        ax[0].set_title('Original picture')
        ax[0].imshow(cropped_spk, cmap=plt.cm.gray)
        ax[0].set_axis_off()

        ax[1].set_title('Transformed picture')
        ax[1].imshow(chull, cmap=plt.cm.gray)
        ax[1].set_axis_off()

        plt.tight_layout()
        plt.show()
    
    # Visualize overlay?
    if Overlay == True:
        overlay_images = cv2.addWeighted(np.float32(cropped_spk),20,np.float32(skeleton),255,0)
        plt.imshow(overlay_images, cmap='gray')
    
    if PlotOut==True:
        overlay_images = cv2.addWeighted(np.float32(cropped_spk),20,np.float32(skeleton),255,0)
        return SpkL, overlay_images
    else:
        return SpkL

# Example:
SL, SLplot = spk_length(cropped_spk, method='skelblur', Overlay=False, PlotCH=False, PlotOut=True)
plt.imshow(SLplot, cmap='gray')
# SL = spk_length(cropped_spk, method='skelblur', Overlay=True, PlotCH=False)

# %%
# %%time

plotname = '.\GIFS\CSSA\Spike\spk_length\\06_bw.jpg'
plt.imsave(plotname, cropped_spk, cmap='gray')

# Severly blur the image
blur = cv2.blur(np.float32(cropped_spk),(100,100))
plotname = '.\GIFS\CSSA\Spike\spk_length\\07_bw_blur.jpg'
plt.imsave(plotname, blur, cmap='gray')

# Threshold the blur
thrb = blur > 0.1
plotname = '.\GIFS\CSSA\Spike\spk_length\\08_bw_thrb.jpg'
plt.imsave(plotname, thrb, cmap='gray')

# Create skeleton
skeleton = skeletonize(thrb)
plotname = '.\GIFS\CSSA\Spike\spk_length\\09_bw_skel.jpg'
plt.imsave(plotname, skeleton, cmap='gray')

# Overlay skeleton
overlay_images = cv2.addWeighted(np.float32(cropped_spk),20,np.float32(skeleton),255,0)
plotname = '.\GIFS\CSSA\Spike\spk_length\\10_bw_SkelOverlay.jpg'
plt.imsave(plotname, overlay_images, cmap='gray')

# %% [markdown]
# ## Treshold for contrours

# %%
# %%time

ResizeFactor=30
thr2=0.8
MinSize=1000

plotname = '.\GIFS\CSSA\Spike\\thresh2\\11_bw.jpg'
plt.imsave(plotname, cropped_spk, cmap='gray')

# Reduce image size
im = Image.fromarray((cropped_gray*255).astype(np.uint8))
(width, height) = (im.width // ResizeFactor, im.height // ResizeFactor)
rescaled_spk = im.resize((width, height))
plotname = '.\GIFS\CSSA\Spike\\thresh2\\12_bw_resized.jpg'
plt.imsave(plotname, np.asarray(rescaled_spk), cmap='gray')


# Increase to original size
(width, height) = (im.width, im.height)
rescaled_spk = rescaled_spk.resize((width, height))
rescaled_spk = np.asarray(rescaled_spk)
plotname = '.\GIFS\CSSA\Spike\\thresh2\\13_bw_SizeRestored.jpg'
plt.imsave(plotname, rescaled_spk, cmap='gray')

# Histogram equalization
rescaled_spk = exposure.equalize_hist(rescaled_spk)
plotname = '.\GIFS\CSSA\Spike\\thresh2\\14_bw_HistEq.jpg'
plt.imsave(plotname, rescaled_spk, cmap='gray')

# Blur with a Gaussian
blurred = filters.gaussian(rescaled_spk, sigma=1, preserve_range=True)
plotname = '.\GIFS\CSSA\Spike\\thresh2\\15_bw_GaussBlur.jpg'
plt.imsave(plotname, blurred, cmap='gray')

# Adaptative equalization
blurred = exposure.equalize_adapthist(blurred)
plotname = '.\GIFS\CSSA\Spike\\thresh2\\16_bw_AdaptHist.jpg'
plt.imsave(plotname, blurred, cmap='gray')

# Normalize
blurred = cv2.normalize(blurred, None, alpha = 0, beta = 255, norm_type = cv2.NORM_MINMAX, dtype = cv2.CV_32F)
blurred = blurred.astype(np.uint8)

if thr2 < 1 == True:
    thr2 = thr2*255
else:
    thr2 = thr2

# Threshold at given %
ret, thresh = cv2.threshold(blurred, thr2, 255, 0)
thresh = np.uint8(thresh)
plotname = '.\GIFS\CSSA\Spike\\thresh2\\17_bw_thresh.jpg'
plt.imsave(plotname, thresh, cmap='gray')

nb_components, output, stats, centroids = cv2.connectedComponentsWithStats(thresh, connectivity=8)
sizes = stats[1:, -1]; nb_components = nb_components - 1    

thresh2 = np.zeros((output.shape))

# Keep only objects with minimum size
for i in range(0, nb_components):
    if sizes[i] >= MinSize:
        thresh2[output == i + 1] = 255

#     plt.imshow(thresh2)
thresh2 = np.uint8(thresh2)
plotname = '.\GIFS\CSSA\Spike\\thresh2\\18_bw_thresh2.jpg'
plt.imsave(plotname, thresh2, cmap='gray')

# %% [markdown]
# ## Watershed

# %%
# %%time

plotname = '.\GIFS\CSSA\Spike\Watershed\\01_rgb.jpg'
plt.imsave(plotname, cropped_rgb)

# Rescale to 10% of original
rescaled_spk = rescale(cropped_rgb[...], 0.1, preserve_range=False, multichannel=True, anti_aliasing=True)
# plt.imshow(rescaled_spk)
plotname = '.\GIFS\CSSA\Spike\Watershed\\02_rescaled.jpg'
plt.imsave(plotname, rescaled_spk)


# Erosion
kernel = cv2.getStructuringElement(cv2.MORPH_CROSS,(3,3))
erosion = cv2.erode(rescaled_spk,kernel,iterations = 1)
# plt.imshow(erosion)
plotname = '.\GIFS\CSSA\Spike\Watershed\\03_erosion.jpg'
plt.imsave(plotname, erosion)

# Opening
kernel = np.ones((1,1),np.uint8)
opening = cv2.morphologyEx(erosion, cv2.MORPH_OPEN, kernel, iterations = 10)
# plt.imshow(opening)
plotname = '.\GIFS\CSSA\Spike\Watershed\\04_opening.jpg'
plt.imsave(plotname, opening)

# Resize
rescaled_spk2 = Image.fromarray((rescaled_spk * 255).astype(np.uint8))
rescaled_spk2 = rescaled_spk2.resize((cropped_rgb.shape[1],cropped_rgb.shape[0]))
# plt.imshow(rescaled_spk2)
# rescaled_spk2.size
opening = np.asarray(rescaled_spk2)
# plt.imshow(opening)
plotname = '.\GIFS\CSSA\Spike\Watershed\\05_ResizedOpening.jpg'
plt.imsave(plotname, opening)


# Convert rgb to gray
gray_spklts = opening @ [0.2126, 0.7152, 0.0722]
# plt.imshow(gray_spklts)
plotname = '.\GIFS\CSSA\Spike\Watershed\\06_gray.jpg'
plt.imsave(plotname, gray_spklts, cmap='gray')

# Binarize gray
bw_spklts = gray_spklts > 0
# plt.imshow(bw_spklts)
plotname = '.\GIFS\CSSA\Spike\Watershed\\07_binary.jpg'
plt.imsave(plotname, bw_spklts, cmap='gray')

# Get distances
distance = ndi.distance_transform_edt(bw_spklts)
# plt.imshow(-distance)
plotname = '.\GIFS\CSSA\Spike\Watershed\\08_distance.jpg'
plt.imsave(plotname, distance, cmap='gray')

MinDist=50
# Get max peaks
coords = peak_local_max(distance, min_distance=MinDist, labels=bw_spklts)
# plt.imshow(coords)
plotname = '.\GIFS\CSSA\Spike\Watershed\\09_coords.jpg'
plt.imsave(plotname, coords, cmap='gray')

mask = np.zeros(distance.shape, dtype=bool)
mask[tuple(coords.T)] = True
markers, spikelets = ndi.label(mask)
plotname = '.\GIFS\CSSA\Spike\Watershed\\10_markers.jpg'
plt.imsave(plotname, markers, cmap='gray')

# Watershed
labels = watershed(-distance, markers, mask=bw_spklts)
#     plt.imshow(labels)
plotname = '.\GIFS\CSSA\Spike\Watershed\\11_labels.jpg'
plt.imsave(plotname, labels)

labels2 = np.unique(labels[labels > 0])

C = []

for label in labels2:
        y = labels == label
        y = y * 255
        y = y.astype('uint8')
        contours, hierarchy = cv2.findContours(y, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        # len(contours)
        contours = np.squeeze(contours)
        C.append(contours)

#         plt.imshow(d[2])

contours = C

OutImage = cropped_rgb.copy()

# Plot all found contours
OutImage = cv2.drawContours(OutImage, contours, -1, (0,0,0), 10);
# plt.imshow(OutImage)

count = 11

for c in contours:
    try:

        # Generate random colors
        random_channels = (np.random.choice(range(256), size=3))
        rr = int(random_channels[0])
        rg = int(random_channels[1])
        rb = int(random_channels[2])

        ellipse = cv2.fitEllipse(c)
        OutImage = cv2.ellipse(OutImage,ellipse,(rr,rg,rb),10);

        count = count+1
        plotname = '.\GIFS\CSSA\Spike\Watershed\\' + str(count) + '_contour.jpg'
        plt.imsave(plotname, OutImage)

        # Fit a line 
        rows,cols = OutImage.shape[:2]
        [vx,vy,x,y] = cv2.fitLine(c, cv2.DIST_L2,0,0.01,0.01);
        lefty = int((-x*vy/vx) + y)
        righty = int(((cols-x)*vy/vx)+y)
        # OutImage = cv2.line(OutImage,(cols-1,righty),(0,lefty),(rr,rg,rb),3);

        # Slope from tope left, which is is the origin [0,0]
        rise = (0,lefty)[1] - (cols-1,righty)[1]
        run = cols
        Slope = rise/run
        Slopes.append(Slope) 
    except:
        pass

# %%
LabelSpklts(cropped_rgb, MinDist=50, labels_out=False, n_spklt=False, ElliPlot=False, Plot=True)

# %% [markdown]
# ## Distances all

# %% [markdown]
# ## Contours

# %%
# Contours
labels_cont = CountorProps(cropped_rgb, cropped_lab, cropped_hsv, thresh2, ImagePath=img_name, ResizeFactor=30, MinSize = 1000, thr2=0.8, plot=False)

# %% [markdown]
# # Elliptical Fourier Descriptors

# %%
def SpykEFD_Batch(Images):
    import time
    from datetime import datetime, date
    import spatial_efd
    import pyefd
    from pyefd import elliptic_fourier_descriptors
    from pyefd import normalize_efd
    
    n_harmonics = 100
    
    EDF_cols = ['An','Bn','Cn','Dn']
    EDF_nums = list(range(1,n_harmonics+1))
    EDF_nums = [str(x) for x in EDF_nums]
    Cols = np.char.add(EDF_cols,np.array(EDF_nums)[:,None])
    Cols = Cols.reshape(1,4*n_harmonics)
    Cols = Cols.tolist()
    Cols = Cols[0]

    start_time = time.time()
    
    Nimages = str(len(Images))

    EFD_data = pd.DataFrame()
    
    Counter=0

    for img_name in Images:
        
        try:

            Counter = Counter+1
            Progress = str(Counter) + "/" + Nimages
            # img_name=Images[0]
            now = datetime.now().strftime("%H:%M:%S")
            print("Processing image " + Progress + ": ", img_name + " at " + now)
            # img_name = Images[9]

            # Set the initial time per image
            image_time = time.time()
            
            # Get only BW
            I = RemoveBackground(img_name, OtsuScaling=0.25, 
                                 rgb_out=False, gray_out=False, 
                                 lab_out=False, hsv_out=False, 
                                 bw_out=True)

            labeled_spks, num_spikes = label(I[0], return_num = True)

            CoeffsPerSpike = pd.DataFrame()

            # Start at 1 so it ignores background (0) 
            for Label in range(1, num_spikes+1):                

                print("Processing spike ", Label)
        #         plt.imshow(labeled_spks==2)
                spk = labeled_spks==Label
                # io.imshow(spk)

                # Crop spike
                slice_x, slice_y = ndimage.find_objects(spk)[0]
                cropped_spk = spk[slice_x, slice_y]

                bw = np.pad(cropped_spk, pad_width=[(100, 100),(100, 100)], mode='constant')
                bw = ndimage.binary_fill_holes(bw)
                bw = np.uint8(bw)
                # plt.imshow(bw)

                contour, hierarchy = cv2.findContours(bw,cv2.RETR_CCOMP,cv2.CHAIN_APPROX_SIMPLE)
                contour = np.squeeze(contour)

                x = contour[:,0]
                y = contour[:,1]
                # harmonics=1000

                # First n coefficients
                coeffs100 = spatial_efd.CalculateEFD(x,y,n_harmonics)
                coeffs100, rotation = spatial_efd.normalize_efd(coeffs100, size_invariant=True)
                coeffs100 = coeffs100.reshape(1,4*n_harmonics)

                # Min number of coefficients
                # Nyquist Freqency: maximum number of harmonics that can be computed for a given contour
                nyquist = spatial_efd.Nyquist(x)
                tmpcoeffs = spatial_efd.CalculateEFD(x, y, nyquist+1)
                harmonics = spatial_efd.FourierPower(tmpcoeffs, x)
                # coeffs_min = spatial_efd.CalculateEFD(x, y, harmonics)
                # coeffs_min, rotation = spatial_efd.normalize_efd(coeffs_min, size_invariant=True)

                coeffs100 = pd.DataFrame(coeffs100, columns=Cols)
                coeffs100['Image_Name'] = img_name.split('\\')[-1]
                coeffs100['Spike_Label'] = Label
                coeffs100['Min_Coeffs'] = harmonics

                CoeffsPerSpike = CoeffsPerSpike.append(coeffs100)
                    
        except:
            pass

        EFD_data = EFD_data.append(CoeffsPerSpike)

        # How long did it take to run this image?
        print("Image " + img_name.split('\\')[-1] + ", " + Progress + ", was fully processed in " + str(round(time.time() - image_time, 1)) + " seconds. " + "\n")


    # How long did it take to run the whole code?
    print("This entire code took", str(round(time.time() - start_time, 1)), "seconds to run.")
    
    return EFD_data

# %%
def SpykEFD_Batch(Images):
    import time
    from datetime import datetime, date
    import spatial_efd
    import pyefd
    from pyefd import elliptic_fourier_descriptors
    from pyefd import normalize_efd
    
    EDF_cols = ['An','Bn','Cn','Dn']
    EDF_nums = list(range(1,1001))
    EDF_nums = [str(x) for x in EDF_nums]
    Cols = np.char.add(EDF_cols,np.array(EDF_nums)[:,None])
    Cols = Cols.reshape(1,4000)
    Cols = Cols.tolist()
    Cols = Cols[0]

    start_time = time.time()
    
    Nimages = str(len(Images))

    EFD_data = pd.DataFrame()
    
    Counter=0

    for img_name in Images:
        
        try:

            Counter = Counter+1
            Progress = str(Counter) + "/" + Nimages
            # img_name=Images[0]
            now = datetime.now().strftime("%H:%M:%S")
            print("Processing image " + Progress + ": ", img_name + " at " + now)
            # img_name = Images[9]

            # Set the initial time per image
            image_time = time.time()
            
            # Get only BW
            I = RemoveBackground(img_name, OtsuScaling=0.25, 
                                 rgb_out=False, gray_out=False, 
                                 lab_out=False, hsv_out=False, 
                                 bw_out=True)

            labeled_spks, num_spikes = label(I[0], return_num = True)

            CoeffsPerSpike = pd.DataFrame()

            # Start at 1 so it ignores background (0) 
            for Label in range(1, num_spikes+1):                

                print("Processing spike ", Label)
        #         plt.imshow(labeled_spks==2)
                spk = labeled_spks==Label
                # io.imshow(spk)

                # Crop spike
                slice_x, slice_y = ndimage.find_objects(spk)[0]
                cropped_spk = spk[slice_x, slice_y]

                bw = np.pad(cropped_spk, pad_width=[(100, 100),(100, 100)], mode='constant')
                bw = ndimage.binary_fill_holes(bw)
                bw = np.uint8(bw)
                # plt.imshow(bw)

                contour, hierarchy = cv2.findContours(bw,cv2.RETR_CCOMP,cv2.CHAIN_APPROX_NONE)
                contour = np.squeeze(contour)

                x = contour[:,0]
                y = contour[:,1]
                # harmonics=1000

                # First 1000 coefficients
                coeffs1000 = spatial_efd.CalculateEFD(x,y,1000)
                coeffs1000, rotation = spatial_efd.normalize_efd(coeffs1000, size_invariant=True)
                coeffs1000 = coeffs1000.reshape(1,4000)

                # Min number of coefficients
                # Nyquist Freqency: maximum number of harmonics that can be computed for a given contour
                nyquist = spatial_efd.Nyquist(x)
                tmpcoeffs = spatial_efd.CalculateEFD(x, y, nyquist+1)
                harmonics = spatial_efd.FourierPower(tmpcoeffs, x)
                # coeffs_min = spatial_efd.CalculateEFD(x, y, harmonics)
                # coeffs_min, rotation = spatial_efd.normalize_efd(coeffs_min, size_invariant=True)

                coeffs1000 = pd.DataFrame(coeffs1000, columns=Cols)
                coeffs1000['Image_Name'] = img_name.split('\\')[-1]
                coeffs1000['Spike_Label'] = Label
                coeffs1000['Min_Coeffs'] = harmonics

                CoeffsPerSpike = CoeffsPerSpike.append(coeffs1000)
                    
        except:
            pass

        EFD_data = EFD_data.append(CoeffsPerSpike)

        # How long did it take to run this image?
        print("Image " + img_name.split('\\')[-1] + ", " + Progress + ", was fully processed in " + str(round(time.time() - image_time, 1)) + " seconds. " + "\n")


    # How long did it take to run the whole code?
    print("This entire code took", str(round(time.time() - start_time, 1)), "seconds to run.")
    
    return EFD_data

# %% [markdown]
# ## PGR Roseau

# %%
# %%time

from datetime import datetime, date

from SpykFunctions import *

path = r'./Images/PGR_Roseau2021'
# path = r'./Images/TROE2021'
# path = r'./Images/PGR_GH2021'
Images = ListImages(path, imgformat=".tif", recursive=False)
# Images

# %%
Images

# %%
# %%time

EFD_Data = SpykEFD_Batch(Images)

# %%
Today = date.today().strftime("%Y%m%d")

EFD_Data.to_csv(".\Output\PGRRoseau_EFD100_CHAINCODE_{}.csv".format(Today), index=False)
# Wall time: 22min 51s for CHAINSIMPLE

# %% [markdown]
# ## PGR GH

# %%
# %%time

from datetime import datetime, date

from SpykFunctions import *

# path = r'./Images/PGR_Roseau2021'
# path = r'./Images/TROE2021'
path = r'./Images/PGR_GH2021'
Images = ListImages(path, imgformat=".tif", recursive=False)
# Images
# Out:
# Wall time: 13 ms

# %%
# len(Images)
# Out:
# 111

# %%
# %%time

EFD_Data = SpykEFD_Batch(Images)

# %%
Today = date.today().strftime("%Y%m%d")

EFD_Data.to_csv(".\Output\PGRGH_EFD100_CHAINCODE_{}.csv".format(Today), index=False)
# Wall time: 32min 7s for CHAINSIMPLE

# %% [markdown]
# ## TROE 2021

# %%
# %%time


from SpykFunctions import *

# path = r'./Images/PGR_Roseau2021'
path = r'./Images/TROE2021'
# path = r'./Images/PGR_GH2021'
Images = ListImages(path, imgformat=".tif", recursive=False)
# Images
# Spikes_data, Contours_data, Spklts_data, Distances_data = SpykBatch(Images, TROE2020=False)

# %%
Images

# %%
# %%time

EFD_Data = SpykEFD_Batch(Images)

# Wall time: 3h 29min 5s for CHAINSIMPLE

# %%
from datetime import datetime, date

Today = date.today().strftime("%Y%m%d")

EFD_Data.to_csv(".\Output\TROE2021_EFD100_CHAINCODE_{}.csv".format(Today), index=False)

# %%
#

# %%
# %%time


from SpykFunctions import *

path = r'./Images/PGR_Roseau2021'
# path = r'./Images/TROE2021'
# path = r'./Images/PGR_GH2021'
Images = ListImages(path, imgformat=".tif", recursive=False)
# Out:
# Wall time: 4 ms

# %%
# Read image

# scn1 = "./Images/TROE2021/p003P1812.tif"
# scn2 = "./Images/TROE2021/p011P0517.tif"
scn1 = Images[0]
# scn2 = Images[1]


img1 = io.imread(scn1)
# img1 = img1[6916:7016, 5004:5104, 0]
img1 = img1[6816:7016, 4904:5104, 0]  # glass only
T1 = filters.threshold_otsu(img1)
img1 = img1>50
plt.imshow(img1)

np.sum(img1 == 1)
 # Convert to gray
# gray0 = img1 @ [0.2126, 0.7152, 0.0722]
# Out:
# 20524

# %%
img2 = io.imread(scn2)
img2 = img2[6916:7016, 5004:5104, 0]
T2 = filters.threshold_otsu(img2)
# img2 = img2 > T2
img2 = img2>50
plt.imshow(img2)

# %%
n_white_pix = np.sum(img2 == 1)
n_white_pix
# Out:
# 8256

# %%
# %%time

Image_Name = []
AreaT1 = []
AreaT2 = []
Scanner = []

for i in Images:
    img0 = io.imread(i)
    img0 = img0[6816:7016, 4904:5104, 0]
    T_Otsu = filters.threshold_otsu(img0)
    img1 = img0 > T_Otsu
    img2 = img0 > 50
    
    area_t1 = np.sum(img1 == 1)
    area_t2 = np.sum(img2 == 1)
    
    Image_Name.append(i)
    AreaT1.append(area_t1)
    AreaT2.append(area_t2)
    
    if area_t2 > 15000:
        scn = "SCN1"
    else:
        scn = "SCN2"
    
    Scanner.append(scn)
    print('Finished ', i)
    
    

# 1m 51s for TROE 2021
# Out:
# Finished  ./Images/PGR_Roseau2021\S1p01T4R1.tif
# Finished  ./Images/PGR_Roseau2021\S1p02T1R1.tif
# Finished  ./Images/PGR_Roseau2021\S1p03T3R1.tif
# Finished  ./Images/PGR_Roseau2021\S1p04T5R1.tif
# Finished  ./Images/PGR_Roseau2021\S1p05T2R1.tif
# Finished  ./Images/PGR_Roseau2021\S1p06T1R2.tif
# Finished  ./Images/PGR_Roseau2021\S1p07T2R2.tif
# Finished  ./Images/PGR_Roseau2021\S1p08T3R2.tif
# Finished  ./Images/PGR_Roseau2021\S1p09T5R2.tif
# Finished  ./Images/PGR_Roseau2021\S1p10T4R2.tif
# Finished  ./Images/PGR_Roseau2021\S1p11T1R3.tif
# Finished  ./Images/PGR_Roseau2021\S1p12T3R3.tif
# Finished  ./Images/PGR_Roseau2021\S1p13T2R3.tif
# Finished  ./Images/PGR_Roseau2021\S1p14T4R3.tif
# Finished  ./Images/PGR_Roseau2021\S1p15T5R3.tif
# Finished  ./Images/PGR_Roseau2021\S1p16T3R4.tif
# Finished  ./Images/PGR_Roseau2021\S1p17T1R4.tif
# Finished  ./Images/PGR_Roseau2021\S1p18T5R4.tif
# Finished  ./Images/PGR_Roseau2021\S1p19T4R4.tif
# Finished  ./Images/PGR_Roseau2021\S1p20T2R4.tif
# Finished  ./Images/PGR_Roseau2021\S2p01T5R1.tif
# Finished  ./Images/PGR_Roseau2021\S2p02T3R1.tif
# Finished  ./Images/PGR_Roseau2021\S2p03T2R1.tif
# Finished  ./Images/PGR_Roseau2021\S2p04T4R1.tif
# Finished  ./Images/PGR_Roseau2021\S2p05T1R1.tif
# Finished  ./Images/PGR_Roseau2021\S2p06T3R2.tif
# Finished  ./Images/PGR_Roseau2021\S2p07T4R2.tif
# Finished  ./Images/PGR_Roseau2021\S2p08T1R2.tif
# Finished  ./Images/PGR_Roseau2021\S2p09T2R2.tif
# Finished  ./Images/PGR_Roseau2021\S2p10T5R2.tif
# Finished  ./Images/PGR_Roseau2021\S2p11T2R3.tif
# Finished  ./Images/PGR_Roseau2021\S2p12T5R3.tif
# Finished  ./Images/PGR_Roseau2021\S2p13T4R3.tif
# Finished  ./Images/PGR_Roseau2021\S2p14T3R3.tif
# Finished  ./Images/PGR_Roseau2021\S2p15T1R3.tif
# Finished  ./Images/PGR_Roseau2021\S2p16T4R4.tif
# Finished  ./Images/PGR_Roseau2021\S2p17T1R4.tif
# Finished  ./Images/PGR_Roseau2021\S2p18T3R4.tif
# Finished  ./Images/PGR_Roseau2021\S2p19T5R4.tif
# Finished  ./Images/PGR_Roseau2021\S2p20T2R4.tif
# Wall time: 8.87 s

# %%
# %%time

# Image_Name = []
# Area = []
# Scanner = []
# MeanPixel = []

# for i in Images:
#     img1 = io.imread(i)
#     Tape = img1[6936:7016, 5024:5104, :]
#     Glass = img1[6816:6916, 4904:5004, :]  # glass only
#     gray0 = Glass @ [0.2126, 0.7152, 0.0722]
#     # plt.imshow(gray0)
#     # Set image threshold
#     T = filters.threshold_otsu(Tape[:,:,0])
#     Tape = Tape>T
#     # plt.imshow(np.float32(img1))
#     n_white_pix = np.sum(Tape == True)
#     GrayMean = np.mean(gray0)
#     GrayMin = np.min(gray0)
#     GrayMax = np.max(gray0)
#     # T1 = filters.threshold_otsu(img1)
#     # img1 = img1>T
#     # n_white_pix = np.sum(img1 == 1)
    
#     Image_Name.append(i)
#     Area.append(n_white_pix)
#     MeanPixel.append(GrayMean)
    
#     if n_white_pix > 12000:
#         scn = "scn2"
#     else:
#         scn = "scn1"
    
#     Scanner.append(scn)
#     print('Finished ', i)
    
    

# # 1m 51s for TROE 2021

# %%
Image_Name
Area
Scanner
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29628/1370823530.py in <module>
#       1 Image_Name
# ----> 2 Area
#       3 Scanner
#
# NameError: name 'Area' is not defined

# %%
ScannerType = pd.DataFrame()
ScannerType['Image_Name'] = Image_Name
ScannerType['Otsu'] = AreaT1
ScannerType['Red>50'] = AreaT2
ScannerType['Scanner'] = Scanner
# ScannerType['MeanPixel'] = MeanPixel
ScannerType
ScannerType.to_csv(".\Output\PGRRoseau2021_ScannerType.csv", index=False)

# %%
ScannerType
# Out:
#                           Image_Name   Area Scanner   MeanPixel
# 0    ./Images/TROE2021\p003P1812.tif  11908    scn1  110.392792
# 1    ./Images/TROE2021\p004P04--.tif  11893    scn1  110.306341
# 2    ./Images/TROE2021\p005P2103.tif  11981    scn1  111.197221
# 3    ./Images/TROE2021\p006P23--.tif  11942    scn1  110.882648
# 4    ./Images/TROE2021\p007P1404.tif  11998    scn1  110.865807
# ..                               ...    ...     ...         ...
# 523  ./Images/TROE2021\p596P0414.tif  13019    scn2  137.240923
# 524  ./Images/TROE2021\p597P11--.tif  11303    scn1  105.607442
# 525  ./Images/TROE2021\p598P1823.tif  11385    scn1  106.177109
# 526  ./Images/TROE2021\p599P1916.tif  13238    scn2  136.183612
# 527  ./Images/TROE2021\p600P2006.tif  11438    scn1  106.446612
#
# [528 rows x 4 columns]

# %%
M = pd.read_csv('matrix4heatmap.csv')
ylabesls = M["CodeComb"]
M = M.drop("CodeComb", axis=1)
# M = M.rename(columns={"Unnamed: 0": "CodeComb"})

from sklearn.preprocessing import StandardScaler
M_scaled = StandardScaler().fit_transform(M.values)
# pd.DataFrame(M_scaled).reset_index()

# %%
plt.rcParams['figure.dpi'] = 100

sns.set(font_scale=0.3)
ax = sns.heatmap(M_scaled,
                 cmap='YlGnBu',
                 xticklabels=list(M.columns),
                 yticklabels=ylabesls,
                 cbar_kws={"orientation": "horizontal"})
ax.set_aspect("equal")

# %%
list(M.CodeComb)
# Out:
# ['p039P2425.tif_3',
#  'p039P2425.tif_4',
#  'p039P2425.tif_7',
#  'p223P2321.tif_6',
#  'p303P24--.tif_6',
#  'p308P2102.tif_7',
#  'p348P0119.tif_9',
#  'p348P0119.tif_11',
#  'p419P2414.tif_6',
#  'p420P21--.tif_1',
#  'p003P1812.tif_15',
#  'p017P1012.tif_2',
#  'p098P15--.tif_15',
#  'p157P1511.tif_15',
#  'p157P1511.tif_16',
#  'p264P1506.tif_13',
#  'p282P0905.tif_5',
#  'p282P0905.tif_16',
#  'p558P1104.tif_12',
#  'p561P15--.tif_16',
#  'p577P1108.tif_16']

# %%
img_name = Images[1]

# %%
I = RemoveBackground(img_name, OtsuScaling=0.25, 
                                 rgb_out=True, gray_out=True, 
                                 lab_out=True, hsv_out=True, 
                                 bw_out=True)
rgb0 = I[0]
gray0 = I[1]
lab0 = I[2]
hsv0 = I[3]
bw0 = I[4]

# %%
plt.rcParams['figure.dpi'] = 300
plt.imshow(I[0])

# %%
# Label spikes
labeled_spks, num_spikes = label(bw0, return_num = True)
# plt.imshow(labeled_spks==1)
 
Label = 1

spk = labeled_spks==Label
io.imshow(spk)

# Crop spike
# slice_x, slice_y = ndimage.find_objects(spk)[0]
# cropped_spk = spk[slice_x, slice_y]
# cropped_rgb = rgb0[slice_x, slice_y]
# cropped_rgb = np.where(cropped_spk[..., None], cropped_rgb, 0)
# cropped_gray = color.rgb2gray(cropped_rgb)
# cropped_lab = color.rgb2lab(cropped_rgb)
# cropped_hsv = color.rgb2hsv(cropped_rgb)
#         io.imshow(cropped_spk)
