# %% [markdown]
# # Execute SpykProps on a folder with images

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# cd '/content/drive/MyDrive/M.Sc/THESIS/ImageAnalysis/SpikeProperties/Spyk_Prop'

# %%
# pip install skan

# %%
# import sys
# sys.path.append('/content/drive/MyDrive/M.Sc/THESIS/ImageAnalysis/SpikeProperties/Spyk_Prop')
# sys.path

# %% [markdown]
# ## Define the function

# %%
def SpykBatch(Images, TROE2020=False):
    
    import time
    from datetime import datetime, date

    start_time = time.time()
    
    Nimages = str(len(Images))
    
    Spikes_data = pd.DataFrame()
    Contours_data = pd.DataFrame()
    Spklts_data = pd.DataFrame()
    Distances_data = pd.DataFrame()
    
    Counter=0


    for img_name in Images:
        
        try:

            Counter = Counter+1
            Progress = str(Counter) + "/" + Nimages
            # img_name=Images[0]
            now = datetime.now().strftime("%H:%M:%S")
            print("Processing image " + Progress + ": ", img_name + " at " + now)
            # img_name = Images[9]

            # Set the initial time per image
            image_time = time.time()

            # Remove background and create images
            I = RemoveBackground(img_name, OtsuScaling=0.25, rgb_out=True, gray_out=True, lab_out=True, hsv_out=True, bw_out=True)
            rgb0 = I[0]
            gray0 = I[1]
            lab0 = I[2]
            hsv0 = I[3]
            bw0 = I[4]

            # Enumerate spikes
        #     EnumerateSpkCV(bw0, rgb0, TextSize=5, TROE2020=False)

            # Collect spikes data
            df = SpikesDF(I=I, ImagePath=img_name, RemoveBG=False, rm_envelope=False)

            # Label spikes
            labeled_spks, num_spikes = label(bw0, return_num = True)
            # plt.imshow(labeled_spks==1)

            # Spike lengths
            SpkLengths = []

            # Spike distances from each other
            SpkDists = []

            # TROE2021 and PGR start at 2. Ignore background (0) and envelope (1)
            # if TROE2020==False:
            #     FirstSpk = 2
            # else:
            #     FirstSpk = 1


            ContoursPerSpk = pd.DataFrame()
            SpkltsPerSpk = pd.DataFrame()
            DistancesPerSpk = pd.DataFrame()    



            # Start at 1 so it ignores background (0) 
            for Label in range(1, num_spikes+1):
                
                try:
                    print("Processing spike ", Label)
            #         plt.imshow(labeled_spks==2)

                    spk = labeled_spks==Label
                    # io.imshow(spk)

                    # Crop spike
                    slice_x, slice_y = ndimage.find_objects(spk)[0]
                    cropped_spk = spk[slice_x, slice_y]
                    cropped_rgb = rgb0[slice_x, slice_y]
                    cropped_rgb = np.where(cropped_spk[..., None], cropped_rgb, 0)
                    cropped_gray = color.rgb2gray(cropped_rgb)
                    cropped_lab = color.rgb2lab(cropped_rgb)
                    cropped_hsv = color.rgb2hsv(cropped_rgb)
            #         io.imshow(cropped_spk)

                    # Spike length
                    sl = spk_length(cropped_spk, method='skelblur', Overlay=False, PlotCH=False)
                    SpkLengths.append(sl)

                    # Theshold for detection
                    thresh2 = SpkltThresh(cropped_rgb, ResizeFactor=30, thr2=0.8, MinSize=1000)
                    # plt.imshow(thresh2)

                    # Distances between contours
                    D = DistAll(bw=thresh2, HeatMap=False, spike_length=sl)
                    SpkDists.append(D)
                    # Image_Name = [img_name.split('\\')[-1]]
                    # DistMat = pd.DataFrame(list(zip(Image_Name, str(Label), D)), columns = ['Image_Name', 'Spike_Label', 'MatrixD'])

                    # Contours
                    labels_cont = CountorProps(cropped_rgb, cropped_lab, cropped_hsv, thresh2, ImagePath=img_name, ResizeFactor=30, MinSize = 1000, thr2=0.8, plot=False)
                    # Add spike label
                    labels_cont['Spike_Label'] = [str(Label)] * len(labels_cont)

                    # Watershed segments
                    spklts, n_spklts= LabelSpklts(cropped_rgb, MinDist=50, labels_out=True, n_spklt=True, Plot=False)
                    WSProps = ObjProps(labeled=spklts, cropped_rgb=cropped_rgb, cropped_lab=cropped_lab, cropped_hsv=cropped_hsv, ImagePath=img_name, MinSize = 5000)
                    # Add spike label
                    WSProps['Spike_Label'] = [str(Label)] * len(WSProps)

                    ContoursPerSpk = ContoursPerSpk.append(labels_cont)
                    SpkltsPerSpk = SpkltsPerSpk.append(WSProps)
                   
                    # DistancesPerSpk = DistancesPerSpk.append(DistMat)
                    
                except:
                    pass

            Contours_data = Contours_data.append(ContoursPerSpk)
            Spklts_data = Spklts_data.append(SpkltsPerSpk)
            # Distances_data = Distances_data.append(SpkDists)


            # Add spike lengths and append current data frame
            df["SpykLength"] = SpkLengths
            Spikes_data = Spikes_data.append(df)

            # Distances matrix

            # Create columns with image name, spike index, and distances matrix
            Image_Name = img_name.split('\\')[-1]
            Image_Name = [Image_Name] * len(SpkDists)
            Spk_Index = [number for number in range(1, num_spikes+1)]
            # Matrix of distances among detected spikelets
            DistMat = pd.DataFrame(list(zip(Image_Name, Spk_Index, SpkDists)), columns = ['Image_Name', 'Spike_Label', 'MatrixD'])
            # Append
            Distances_data = Distances_data.append(DistMat)

            # How long did it take to run this image?
            print("Image " + img_name.split('\\')[-1] + ", " + Progress + ", was fully processed in " + str(round(time.time() - image_time, 1)) + " seconds. " + "\n")
            
        except:
            pass

    # How long did it take to run the whole code?
    print("This entire code took", str(round(time.time() - start_time, 1)), "seconds to run.")
    
    return Spikes_data, Contours_data, Spklts_data, Distances_data

# %% [markdown]
# ## Batch execution

# %%
# %%time

from SpykFunctions import *

# path = r'./Images/PGR_Roseau2021'
# path = r'./Images/TROE2021'
path = r'./Images/PGR_GH2021'
Images = ListImages(path, imgformat=".tif", recursive=False)

Spikes_data, Contours_data, Spklts_data, Distances_data = SpykBatch(Images, TROE2020=False)
# Out:
# Processing image 1/127:  ./Images/PGR_GH2021\B2p0363T4.tif at 19:29:56
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B2p0363T4.tif, 1/127, was fully processed in 85.2 seconds.
#
# Processing image 2/127:  ./Images/PGR_GH2021\B2p0371T3.tif at 19:31:21
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B2p0371T3.tif, 2/127, was fully processed in 87.1 seconds.
#
# Processing image 3/127:  ./Images/PGR_GH2021\B2p0391T1.tif at 19:32:48
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Image B2p0391T1.tif, 3/127, was fully processed in 58.1 seconds.
#
# Processing image 4/127:  ./Images/PGR_GH2021\B2p0393T6.tif at 19:33:46
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Image B2p0393T6.tif, 4/127, was fully processed in 60.4 seconds.
#
# Processing image 5/127:  ./Images/PGR_GH2021\B2p0401T9.tif at 19:34:47
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B2p0401T9.tif, 5/127, was fully processed in 66.3 seconds.
#
# Processing image 6/127:  ./Images/PGR_GH2021\B2p0407T9.tif at 19:35:53
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Image B2p0407T9.tif, 6/127, was fully processed in 116.6 seconds.
#
# Processing image 7/127:  ./Images/PGR_GH2021\B2p0421T3.tif at 19:37:50
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Image B2p0421T3.tif, 7/127, was fully processed in 91.7 seconds.
#
# Processing image 8/127:  ./Images/PGR_GH2021\B2p0423T2.tif at 19:39:21
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Image B2p0423T2.tif, 8/127, was fully processed in 348.7 seconds.
#
# Processing image 9/127:  ./Images/PGR_GH2021\B2p0435T8.tif at 19:45:10
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Image B2p0435T8.tif, 9/127, was fully processed in 65.9 seconds.
#
# Processing image 10/127:  ./Images/PGR_GH2021\B2p0441T7.tif at 19:46:16
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Image B2p0441T7.tif, 10/127, was fully processed in 40.7 seconds.
#
# Processing image 11/127:  ./Images/PGR_GH2021\B2p0445T1.tif at 19:46:57
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Image B2p0445T1.tif, 11/127, was fully processed in 75.2 seconds.
#
# Processing image 12/127:  ./Images/PGR_GH2021\B2p0449T7.tif at 19:48:12
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Image B2p0449T7.tif, 12/127, was fully processed in 59.0 seconds.
#
# Processing image 13/127:  ./Images/PGR_GH2021\B2p0457T6.tif at 19:49:11
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B2p0457T6.tif, 13/127, was fully processed in 60.9 seconds.
#
# Processing image 14/127:  ./Images/PGR_GH2021\B2p0489T3.tif at 19:50:12
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Processing spike  19
# Processing spike  20
# Processing spike  21
# Processing spike  22
# Processing spike  23
# Processing spike  24
# Processing spike  25
# Processing spike  26
# Processing spike  27
# Processing spike  28
# Image B2p0489T3.tif, 14/127, was fully processed in 260.2 seconds.
#
# Processing image 15/127:  ./Images/PGR_GH2021\B2p0509T4.tif at 19:54:32
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Image B2p0509T4.tif, 15/127, was fully processed in 82.3 seconds.
#
# Processing image 16/127:  ./Images/PGR_GH2021\B2p0517T1.tif at 19:55:54
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Image B2p0517T1.tif, 16/127, was fully processed in 67.9 seconds.
#
# Processing image 17/127:  ./Images/PGR_GH2021\B2p0519T9.tif at 19:57:02
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Image B2p0519T9.tif, 17/127, was fully processed in 102.7 seconds.
#
# Processing image 18/127:  ./Images/PGR_GH2021\B2p0523T9.tif at 19:58:45
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Image B2p0523T9.tif, 18/127, was fully processed in 122.1 seconds.
#
# Processing image 19/127:  ./Images/PGR_GH2021\B2p0533T2.tif at 20:00:47
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Processing spike  19
# Processing spike  20
# Image B2p0533T2.tif, 19/127, was fully processed in 256.5 seconds.
#
# Processing image 20/127:  ./Images/PGR_GH2021\B2p0553T9.tif at 20:05:03
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Image B2p0553T9.tif, 20/127, was fully processed in 63.4 seconds.
#
# Processing image 21/127:  ./Images/PGR_GH2021\B2p0555T7.tif at 20:06:07
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Image B2p0555T7.tif, 21/127, was fully processed in 80.0 seconds.
#
# Processing image 22/127:  ./Images/PGR_GH2021\B2p0565T6.tif at 20:07:27
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Image B2p0565T6.tif, 22/127, was fully processed in 63.2 seconds.
#
# Processing image 23/127:  ./Images/PGR_GH2021\B2p0569T4.tif at 20:08:30
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Image B2p0569T4.tif, 23/127, was fully processed in 64.0 seconds.
#
# Processing image 24/127:  ./Images/PGR_GH2021\B2p0581T2.tif at 20:09:34
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Processing spike  19
# Processing spike  20
# Processing spike  21
# Processing spike  22
# Processing spike  23
# Processing spike  24
# Processing spike  25
# Processing spike  26
# Processing spike  27
# Processing spike  28
# Processing spike  29
# Image B2p0581T2.tif, 24/127, was fully processed in 332.2 seconds.
#
# Processing image 25/127:  ./Images/PGR_GH2021\B2p0595T9.tif at 20:15:06
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Image B2p0595T9.tif, 25/127, was fully processed in 74.1 seconds.
#
# Processing image 26/127:  ./Images/PGR_GH2021\B2p0597T4.tif at 20:16:20
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Image B2p0597T4.tif, 26/127, was fully processed in 92.7 seconds.
#
# Processing image 27/127:  ./Images/PGR_GH2021\B2p0599T3.tif at 20:17:53
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Processing spike  19
# Processing spike  20
# Processing spike  21
# Processing spike  22
# Processing spike  23
# Processing spike  24
# Processing spike  25
# Processing spike  26
# Processing spike  27
# Processing spike  28
# Processing spike  29
# Processing spike  30
# Image B2p0599T3.tif, 27/127, was fully processed in 130.8 seconds.
#
# Processing image 28/127:  ./Images/PGR_GH2021\B2p0601T7.tif at 20:20:04
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B2p0601T7.tif, 28/127, was fully processed in 48.3 seconds.
#
# Processing image 29/127:  ./Images/PGR_GH2021\B2p0613T2.tif at 20:20:52
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B2p0613T2.tif, 29/127, was fully processed in 98.3 seconds.
#
# Processing image 30/127:  ./Images/PGR_GH2021\B2p0615T1.tif at 20:22:30
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B2p0615T1.tif, 30/127, was fully processed in 62.8 seconds.
#
# Processing image 31/127:  ./Images/PGR_GH2021\B2p0621T6.tif at 20:23:33
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Image B2p0621T6.tif, 31/127, was fully processed in 67.1 seconds.
#
# Processing image 32/127:  ./Images/PGR_GH2021\B2p0629T8.tif at 20:24:40
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Image B2p0629T8.tif, 32/127, was fully processed in 61.9 seconds.
#
# Processing image 33/127:  ./Images/PGR_GH2021\B2p0633T2.tif at 20:25:42
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Image B2p0633T2.tif, 33/127, was fully processed in 94.9 seconds.
#
# Processing image 34/127:  ./Images/PGR_GH2021\B2p0643T1.tif at 20:27:17
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Image B2p0643T1.tif, 34/127, was fully processed in 100.6 seconds.
#
# Processing image 35/127:  ./Images/PGR_GH2021\B2p0645T8.tif at 20:28:58
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B2p0645T8.tif, 35/127, was fully processed in 55.6 seconds.
#
# Processing image 36/127:  ./Images/PGR_GH2021\B2p0647T1.tif at 20:29:53
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Image B2p0647T1.tif, 36/127, was fully processed in 64.5 seconds.
#
# Processing image 37/127:  ./Images/PGR_GH2021\B2p0649T4.tif at 20:30:58
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Processing spike  19
# Processing spike  20
# Processing spike  21
# Processing spike  22
# Processing spike  23
# Processing spike  24
# Processing spike  25
# Processing spike  26
# Image B2p0649T4.tif, 37/127, was fully processed in 107.0 seconds.
#
# Processing image 38/127:  ./Images/PGR_GH2021\B2p0655T1.tif at 20:32:45
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Image B2p0655T1.tif, 38/127, was fully processed in 65.8 seconds.
#
# Processing image 39/127:  ./Images/PGR_GH2021\B2p0669T7.tif at 20:33:51
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B2p0669T7.tif, 39/127, was fully processed in 67.5 seconds.
#
# Processing image 40/127:  ./Images/PGR_GH2021\B2p0673T7.tif at 20:34:58
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B2p0673T7.tif, 40/127, was fully processed in 52.0 seconds.
#
# Processing image 41/127:  ./Images/PGR_GH2021\B2p0675T4.tif at 20:35:50
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Image B2p0675T4.tif, 41/127, was fully processed in 56.0 seconds.
#
# Processing image 42/127:  ./Images/PGR_GH2021\B2p0677T5.tif at 20:36:46
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Image B2p0677T5.tif, 42/127, was fully processed in 44.9 seconds.
#
# Processing image 43/127:  ./Images/PGR_GH2021\B2p0683T3.tif at 20:37:31
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B2p0683T3.tif, 43/127, was fully processed in 75.2 seconds.
#
# Processing image 44/127:  ./Images/PGR_GH2021\B2p0685T3.tif at 20:38:46
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Image B2p0685T3.tif, 44/127, was fully processed in 65.3 seconds.
#
# Processing image 45/127:  ./Images/PGR_GH2021\B2p0687T6.tif at 20:39:51
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B2p0687T6.tif, 45/127, was fully processed in 63.6 seconds.
#
# Processing image 46/127:  ./Images/PGR_GH2021\B2p0689T2.tif at 20:40:55
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Processing spike  19
# Processing spike  20
# Processing spike  21
# Processing spike  22
# Processing spike  23
# Processing spike  24
# Processing spike  25
# Processing spike  26
# Image B2p0689T2.tif, 46/127, was fully processed in 162.9 seconds.
#
# Processing image 47/127:  ./Images/PGR_GH2021\B2p0699T1.tif at 20:43:38
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Image B2p0699T1.tif, 47/127, was fully processed in 101.6 seconds.
#
# Processing image 48/127:  ./Images/PGR_GH2021\B2p0701T2.tif at 20:45:20
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Image B2p0701T2.tif, 48/127, was fully processed in 84.5 seconds.
#
# Processing image 49/127:  ./Images/PGR_GH2021\B2p0703T3.tif at 20:46:44
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B2p0703T3.tif, 49/127, was fully processed in 55.0 seconds.
#
# Processing image 50/127:  ./Images/PGR_GH2021\B2p0705T9.tif at 20:47:39
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Image B2p0705T9.tif, 50/127, was fully processed in 53.2 seconds.
#
# Processing image 51/127:  ./Images/PGR_GH2021\B2p0713T9.tif at 20:48:32
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Image B2p0713T9.tif, 51/127, was fully processed in 97.7 seconds.
#
# Processing image 52/127:  ./Images/PGR_GH2021\B2p0715T7.tif at 20:50:10
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Processing spike  19
# Image B2p0715T7.tif, 52/127, was fully processed in 56.9 seconds.
#
# Processing image 53/127:  ./Images/PGR_GH2021\B2p0717T9.tif at 20:51:07
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Image B2p0717T9.tif, 53/127, was fully processed in 56.9 seconds.
#
# Processing image 54/127:  ./Images/PGR_GH2021\B2p0719T5.tif at 20:52:04
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Image B2p0719T5.tif, 54/127, was fully processed in 68.5 seconds.
#
# Processing image 55/127:  ./Images/PGR_GH2021\B3p0725T3.tif at 20:53:12
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B3p0725T3.tif, 55/127, was fully processed in 63.6 seconds.
#
# Processing image 56/127:  ./Images/PGR_GH2021\B3p0727T3.tif at 20:54:16
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Image B3p0727T3.tif, 56/127, was fully processed in 55.9 seconds.
#
# Processing image 57/127:  ./Images/PGR_GH2021\B3p0729T8.tif at 20:55:12
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Image B3p0729T8.tif, 57/127, was fully processed in 68.7 seconds.
#
# Processing image 58/127:  ./Images/PGR_GH2021\B3p0737T7.tif at 20:56:21
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Image B3p0737T7.tif, 58/127, was fully processed in 61.1 seconds.
#
# Processing image 59/127:  ./Images/PGR_GH2021\B3p0741T8.tif at 20:57:22
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B3p0741T8.tif, 59/127, was fully processed in 64.3 seconds.
#
# Processing image 60/127:  ./Images/PGR_GH2021\B3p0743T4.tif at 20:58:26
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Image B3p0743T4.tif, 60/127, was fully processed in 96.2 seconds.
#
# Processing image 61/127:  ./Images/PGR_GH2021\B3p0751T3.tif at 21:00:02
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Image B3p0751T3.tif, 61/127, was fully processed in 77.1 seconds.
#
# Processing image 62/127:  ./Images/PGR_GH2021\B3p0753T9.tif at 21:01:19
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Image B3p0753T9.tif, 62/127, was fully processed in 70.6 seconds.
#
# Processing image 63/127:  ./Images/PGR_GH2021\B3p0755T6.tif at 21:02:30
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B3p0755T6.tif, 63/127, was fully processed in 57.1 seconds.
#
# Processing image 64/127:  ./Images/PGR_GH2021\B3p0757T7.tif at 21:03:27
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Image B3p0757T7.tif, 64/127, was fully processed in 65.9 seconds.
#
# Processing image 65/127:  ./Images/PGR_GH2021\B3p0759T6.tif at 21:04:33
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Image B3p0759T6.tif, 65/127, was fully processed in 35.4 seconds.
#
# Processing image 66/127:  ./Images/PGR_GH2021\B3p0767T6.tif at 21:05:08
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B3p0767T6.tif, 66/127, was fully processed in 57.4 seconds.
#
# Processing image 67/127:  ./Images/PGR_GH2021\B3p0769T9.tif at 21:06:06
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B3p0769T9.tif, 67/127, was fully processed in 63.7 seconds.
#
# Processing image 68/127:  ./Images/PGR_GH2021\B3p0771T4.tif at 21:07:09
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Processing spike  19
# Processing spike  20
# Processing spike  21
# Processing spike  22
# Processing spike  23
# Processing spike  24
# Processing spike  25
# Processing spike  26
# Processing spike  27
# Processing spike  28
# Processing spike  29
# Processing spike  30
# Processing spike  31
# Processing spike  32
# Processing spike  33
# Processing spike  34
# Processing spike  35
# Image B3p0771T4.tif, 68/127, was fully processed in 106.6 seconds.
#
# Processing image 69/127:  ./Images/PGR_GH2021\B3p0773T2.tif at 21:08:56
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Image B3p0773T2.tif, 69/127, was fully processed in 72.4 seconds.
#
# Processing image 70/127:  ./Images/PGR_GH2021\B3p0775T7.tif at 21:10:08
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Image B3p0775T7.tif, 70/127, was fully processed in 62.3 seconds.
#
# Processing image 71/127:  ./Images/PGR_GH2021\B3p0781T2.tif at 21:11:11
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Image B3p0781T2.tif, 71/127, was fully processed in 93.7 seconds.
#
# Processing image 72/127:  ./Images/PGR_GH2021\B3p0787T1.tif at 21:12:44
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B3p0787T1.tif, 72/127, was fully processed in 67.7 seconds.
#
# Processing image 73/127:  ./Images/PGR_GH2021\B3p0795T8.tif at 21:13:52
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Image B3p0795T8.tif, 73/127, was fully processed in 36.2 seconds.
#
# Processing image 74/127:  ./Images/PGR_GH2021\B3p0799T1.tif at 21:14:28
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Image B3p0799T1.tif, 74/127, was fully processed in 58.5 seconds.
#
# Processing image 75/127:  ./Images/PGR_GH2021\B3p0805T8.tif at 21:15:27
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Image B3p0805T8.tif, 75/127, was fully processed in 51.7 seconds.
#
# Processing image 76/127:  ./Images/PGR_GH2021\B3p0817T3.tif at 21:16:18
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B3p0817T3.tif, 76/127, was fully processed in 86.9 seconds.
#
# Processing image 77/127:  ./Images/PGR_GH2021\B3p0819T4.tif at 21:17:45
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Processing spike  19
# Processing spike  20
# Processing spike  21
# Processing spike  22
# Processing spike  23
# Processing spike  24
# Processing spike  25
# Processing spike  26
# Processing spike  27
# Processing spike  28
# Processing spike  29
# Processing spike  30
# Image B3p0819T4.tif, 77/127, was fully processed in 148.9 seconds.
#
# Processing image 78/127:  ./Images/PGR_GH2021\B3p0823T7.tif at 21:20:14
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Image B3p0823T7.tif, 78/127, was fully processed in 73.6 seconds.
#
# Processing image 79/127:  ./Images/PGR_GH2021\B3p0833T6.tif at 21:21:28
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Image B3p0833T6.tif, 79/127, was fully processed in 72.7 seconds.
#
# Processing image 80/127:  ./Images/PGR_GH2021\B3p0853T3.tif at 21:22:41
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Image B3p0853T3.tif, 80/127, was fully processed in 71.1 seconds.
#
# Processing image 81/127:  ./Images/PGR_GH2021\B3p0855T8.tif at 21:23:52
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B3p0855T8.tif, 81/127, was fully processed in 45.9 seconds.
#
# Processing image 82/127:  ./Images/PGR_GH2021\B3p0863T7.tif at 21:24:38
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Image B3p0863T7.tif, 82/127, was fully processed in 54.1 seconds.
#
# Processing image 83/127:  ./Images/PGR_GH2021\B3p0871T4.tif at 21:25:32
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Image B3p0871T4.tif, 83/127, was fully processed in 85.7 seconds.
#
# Processing image 84/127:  ./Images/PGR_GH2021\B3p0879T8.tif at 21:26:57
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Image B3p0879T8.tif, 84/127, was fully processed in 70.4 seconds.
#
# Processing image 85/127:  ./Images/PGR_GH2021\B3p0883T6.tif at 21:28:08
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Image B3p0883T6.tif, 85/127, was fully processed in 47.3 seconds.
#
# Processing image 86/127:  ./Images/PGR_GH2021\B3p0893T9.tif at 21:28:55
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Image B3p0893T9.tif, 86/127, was fully processed in 74.3 seconds.
#
# Processing image 87/127:  ./Images/PGR_GH2021\B3p0903T2.tif at 21:30:09
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Image B3p0903T2.tif, 87/127, was fully processed in 78.3 seconds.
#
# Processing image 88/127:  ./Images/PGR_GH2021\B3p0915T8.tif at 21:31:28
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Image B3p0915T8.tif, 88/127, was fully processed in 49.6 seconds.
#
# Processing image 89/127:  ./Images/PGR_GH2021\B3p0921T3.tif at 21:32:17
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Image B3p0921T3.tif, 89/127, was fully processed in 56.3 seconds.
#
# Processing image 90/127:  ./Images/PGR_GH2021\B3p0925T1.tif at 21:33:14
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Image B3p0925T1.tif, 90/127, was fully processed in 157.6 seconds.
#
# Processing image 91/127:  ./Images/PGR_GH2021\B3p0927T7.tif at 21:35:51
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B3p0927T7.tif, 91/127, was fully processed in 77.4 seconds.
#
# Processing image 92/127:  ./Images/PGR_GH2021\B3p0933T3.tif at 21:37:09
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Processing spike  19
# Processing spike  20
# Image B3p0933T3.tif, 92/127, was fully processed in 122.1 seconds.
#
# Processing image 93/127:  ./Images/PGR_GH2021\B3p0935T7.tif at 21:39:11
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B3p0935T7.tif, 93/127, was fully processed in 59.7 seconds.
#
# Processing image 94/127:  ./Images/PGR_GH2021\B3p0941T6.tif at 21:40:10
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Image B3p0941T6.tif, 94/127, was fully processed in 65.6 seconds.
#
# Processing image 95/127:  ./Images/PGR_GH2021\B3p0947T9.tif at 21:41:16
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Image B3p0947T9.tif, 95/127, was fully processed in 76.4 seconds.
#
# Processing image 96/127:  ./Images/PGR_GH2021\B3p0949T4.tif at 21:42:32
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Image B3p0949T4.tif, 96/127, was fully processed in 113.5 seconds.
#
# Processing image 97/127:  ./Images/PGR_GH2021\B3p0951T6.tif at 21:44:26
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Image B3p0951T6.tif, 97/127, was fully processed in 78.5 seconds.
#
# Processing image 98/127:  ./Images/PGR_GH2021\B3p0955T9.tif at 21:45:44
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Image B3p0955T9.tif, 98/127, was fully processed in 67.1 seconds.
#
# Processing image 99/127:  ./Images/PGR_GH2021\B3p0961T4.tif at 21:46:51
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Processing spike  19
# Processing spike  20
# Processing spike  21
# Processing spike  22
# Processing spike  23
# Processing spike  24
# Processing spike  25
# Processing spike  26
# Processing spike  27
# Processing spike  28
# Image B3p0961T4.tif, 99/127, was fully processed in 121.0 seconds.
#
# Processing image 100/127:  ./Images/PGR_GH2021\B3p0985T8.tif at 21:48:52
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Image B3p0985T8.tif, 100/127, was fully processed in 38.8 seconds.
#
# Processing image 101/127:  ./Images/PGR_GH2021\B3p0987T2.tif at 21:49:31
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B3p0987T2.tif, 101/127, was fully processed in 69.7 seconds.
#
# Processing image 102/127:  ./Images/PGR_GH2021\B3p0991T9.tif at 21:50:41
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B3p0991T9.tif, 102/127, was fully processed in 84.6 seconds.
#
# Processing image 103/127:  ./Images/PGR_GH2021\B3p0993T2.tif at 21:52:05
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Image B3p0993T2.tif, 103/127, was fully processed in 56.9 seconds.
#
# Processing image 104/127:  ./Images/PGR_GH2021\B3p0995T7.tif at 21:53:02
# Processing image 105/127:  ./Images/PGR_GH2021\B3p0997T2.tif at 21:53:03
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B3p0997T2.tif, 105/127, was fully processed in 82.0 seconds.
#
# Processing image 106/127:  ./Images/PGR_GH2021\B3p1001T8.tif at 21:54:25
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Image B3p1001T8.tif, 106/127, was fully processed in 36.6 seconds.
#
# Processing image 107/127:  ./Images/PGR_GH2021\B3p1005T7.tif at 21:55:01
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Image B3p1005T7.tif, 107/127, was fully processed in 54.9 seconds.
#
# Processing image 108/127:  ./Images/PGR_GH2021\B3p1009T1.tif at 21:55:56
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B3p1009T1.tif, 108/127, was fully processed in 53.1 seconds.
#
# Processing image 109/127:  ./Images/PGR_GH2021\B3p1011T3.tif at 21:56:49
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Processing spike  19
# Processing spike  20
# Processing spike  21
# Processing spike  22
# Processing spike  23
# Processing spike  24
# Processing spike  25
# Processing spike  26
# Processing spike  27
# Processing spike  28
# Processing spike  29
# Processing spike  30
# Processing spike  31
# Processing spike  32
# Processing spike  33
# Image B3p1011T3.tif, 109/127, was fully processed in 225.6 seconds.
#
# Processing image 110/127:  ./Images/PGR_GH2021\B3p1013T3.tif at 22:00:35
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Image B3p1013T3.tif, 110/127, was fully processed in 159.7 seconds.
#
# Processing image 111/127:  ./Images/PGR_GH2021\B3p1019T2.tif at 22:03:15
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Processing spike  19
# Processing spike  20
# Processing spike  21
# Processing spike  22
# Processing spike  23
# Processing spike  24
# Processing spike  25
# Processing spike  26
# Processing spike  27
# Processing spike  28
# Processing spike  29
# Processing spike  30
# Processing spike  31
# Image B3p1019T2.tif, 111/127, was fully processed in 190.3 seconds.
#
# Processing image 112/127:  ./Images/PGR_GH2021\B3p1025T4.tif at 22:06:25
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Image B3p1025T4.tif, 112/127, was fully processed in 67.0 seconds.
#
# Processing image 113/127:  ./Images/PGR_GH2021\B3p1027T8.tif at 22:07:32
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Image B3p1027T8.tif, 113/127, was fully processed in 31.3 seconds.
#
# Processing image 114/127:  ./Images/PGR_GH2021\B3p1031T4.tif at 22:08:03
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Image B3p1031T4.tif, 114/127, was fully processed in 58.0 seconds.
#
# Processing image 115/127:  ./Images/PGR_GH2021\B3p1033T4.tif at 22:09:01
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B3p1033T4.tif, 115/127, was fully processed in 98.5 seconds.
#
# Processing image 116/127:  ./Images/PGR_GH2021\B3p1035T8.tif at 22:10:40
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Image B3p1035T8.tif, 116/127, was fully processed in 77.9 seconds.
#
# Processing image 117/127:  ./Images/PGR_GH2021\B3p1043T1.tif at 22:11:58
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Image B3p1043T1.tif, 117/127, was fully processed in 70.3 seconds.
#
# Processing image 118/127:  ./Images/PGR_GH2021\B3p1047T6.tif at 22:13:08
# Processing image 119/127:  ./Images/PGR_GH2021\B3p1049T3.tif at 22:13:09
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Processing spike  19
# Image B3p1049T3.tif, 119/127, was fully processed in 129.9 seconds.
#
# Processing image 120/127:  ./Images/PGR_GH2021\B3p1055T2.tif at 22:15:19
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Processing spike  19
# Image B3p1055T2.tif, 120/127, was fully processed in 75.4 seconds.
#
# Processing image 121/127:  ./Images/PGR_GH2021\B3p1057T7.tif at 22:16:34
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B3p1057T7.tif, 121/127, was fully processed in 51.0 seconds.
#
# Processing image 122/127:  ./Images/PGR_GH2021\B3p1063T9.tif at 22:17:25
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Image B3p1063T9.tif, 122/127, was fully processed in 53.7 seconds.
#
# Processing image 123/127:  ./Images/PGR_GH2021\B3p1065T6.tif at 22:18:19
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Image B3p1065T6.tif, 123/127, was fully processed in 62.7 seconds.
#
# Processing image 124/127:  ./Images/PGR_GH2021\B3p1073T6.tif at 22:19:21
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Image B3p1073T6.tif, 124/127, was fully processed in 67.2 seconds.
#
# Processing image 125/127:  ./Images/PGR_GH2021\B3p1075T1.tif at 22:20:29
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Processing spike  18
# Image B3p1075T1.tif, 125/127, was fully processed in 88.5 seconds.
#
# Processing image 126/127:  ./Images/PGR_GH2021\B3p1077T7.tif at 22:21:57
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Processing spike  16
# Processing spike  17
# Image B3p1077T7.tif, 126/127, was fully processed in 70.7 seconds.
#
# Processing image 127/127:  ./Images/PGR_GH2021\B3p1079T1.tif at 22:23:08
# Processing spike  1
# Processing spike  2
# Processing spike  3
# Processing spike  4
# Processing spike  5
# Processing spike  6
# Processing spike  7
# Processing spike  8
# Processing spike  9
# Processing spike  10
# Processing spike  11
# Processing spike  12
# Processing spike  13
# Processing spike  14
# Processing spike  15
# Image B3p1079T1.tif, 127/127, was fully processed in 61.6 seconds.
#
# This entire code took 10453.4 seconds to run.
# Wall time: 2h 54min 13s

# %% [markdown]
# ## Export datasets

# %% [markdown]
# ### TROE 2021

# %%
Today = date.today().strftime("%Y%m%d")

Spikes_data.to_csv(".\Output\TROE2021_SpikeData_{}.csv".format(Today), index=False)
Contours_data.to_csv(".\Output\TROE2021_ContoursData_{}.csv".format(Today), index=False)
Spklts_data.to_csv(".\Output\TROE2021_SpkltsData_{}.csv".format(Today), index=False)
Distances_data.to_csv(".\Output\TROE2021_DistancesData_{}.csv".format(Today), index=False)

# %%
Spikes_data['Image_Name'].value_counts()
# p229P0109.tif     5
# p240P1821.tif     1
# Out:
# 526

# %% [markdown]
# ### PGR GH2021

# %%
Today = date.today().strftime("%Y%m%d")

Spikes_data.to_csv(".\Output\PGRGH2021_SpikeData_{}.csv".format(Today), index=False)
Contours_data.to_csv(".\Output\PGRGH2021_ContoursData_{}.csv".format(Today), index=False)
Spklts_data.to_csv(".\Output\PGRGH2021_SpkltsData_{}.csv".format(Today), index=False)
Distances_data.to_csv(".\Output\PGRGH2021_DistancesData_{}.csv".format(Today), index=False)

# %%
Spikes_data['Image_Name'].value_counts()
# p229P0109.tif     5
# p240P1821.tif     1
# Out:
# 526

# %%
# Images to re-analyze (lower Otsu coefficient) or discard from TROE 2021 
# p080P2527.tif.jpg
# p081P05--.tif.jpg
# p084P0903.tif.jpg

# %%
# %%time

from SpykFunctions import *

path = r'./Images/TROE2021'
Images= ListImages(path, imgformat=".tif", recursive=False)

# ./Images/PGR_Roseau2021\S2p03T2R1.tif

Spikes_data, Contours_data, Spklts_data, Distances_data = SpykBatch([Images[39]], TROE2020=False)

# %% [markdown]
# # Detect fake spikes

# %%
# %%time

from SpykFunctions import *

path = r'./Images/TROE2021'
Images = ListImages(path, imgformat=".tif", recursive=False)

img = Images[3]

# %%
# %%time

img_name = './Images/PGR_Roseau2021\\S1p20T2R4.tif'
# plt.imshow(plt.imread(img_name))

# Remove background and create images
I = RemoveBackground(img_name, OtsuScaling=0.25, rgb_out=True, gray_out=False, lab_out=False, hsv_out=False, bw_out=True)
rgb0 = I[0]
bw0 = I[1]
# gray0 = I[1]
# lab0 = I[2]
# hsv0 = I[3]
# bw0 = I[4]

plt.rcParams['figure.dpi'] = 300

# Enumerate spikes
EnumerateSpkCV(bw0, rgb0, TextSize=5, TROE2020=False)

# %%
## Fake spikes
S1p08T3R2.tif = 21, 23
S1p10T4R2.tif = 22
S1p12T3R3.tif = 19, 21

# %% [markdown]
# # Enumerate all images

# %%
def EnumBatch(Images, TROE2020=False, TextSize=3, OtsuScaling=0.25):
    
    import time
    start_time = time.time()
    
    Nimages = str(len(Images))
    Counter=0
    
    for img_name in Images:

        Counter = Counter+1
        Progress = str(Counter) + "/" + Nimages
        # img_name=Images[0]
        print("Enumerating image " + Progress + ": ", img_name)

        # Set the initial time per image
        image_time = time.time()

        # Remove background and create images
        I = RemoveBackground(img_name, OtsuScaling=OtsuScaling, rgb_out=True, gray_out=False, lab_out=False, hsv_out=False, bw_out=True)
        rgb0 = I[0]
        bw0 = I[1]

        EnumPlot = EnumerateSpkCV(bw0, rgb0, TextSize=TextSize, TROE2020=False, Plot=False, PlotOut=True)
        ThisImage = img_name.split('/')[-1:]
        plotname = '.\Images\ENUMERATED\\' + ThisImage[0] + '.jpg'
        plt.imsave(plotname, EnumPlot)           

        # How long did it take to run this image?
        print("Image " + img_name.split('\\')[-1] + ", " + Progress + ", was enumerated in " + str(round(time.time() - image_time, 1)) + " seconds." + "\n")
            
            
    # How long did it take to run the whole code?
    print("This entire code took", str(round(time.time() - start_time, 1)), "seconds to run.")

# %% [markdown]
# ## Enumerate PGR Roseau2021

# %%
# %%time
path = r'./Images/PGR_Roseau2021'
Images = ListImages(path, imgformat=".tif", recursive=False)

EnumBatch(Images, TROE2020=False, TextSize=3)
# Finished in about 4min (236.7 sec)

# %% [markdown]
# ## Enumerate TROE2021

# %%
# %%time
path = r'./Images/TROE2021'
Images = ListImages(path, imgformat=".tif", recursive=False)

EnumBatch(Images, TROE2020=False, TextSize=3)
# Finished in over 2h and 7min  ( 7638.1 sec)

# %% [markdown]
# ## Enumerate PGR GH2021

# %%
# %%time
# from SpykFunctions import *

path = r'./Images/PGR_GH2021'
Images = ListImages(path, imgformat=".tif", recursive=False)

EnumBatch(Images, TROE2020=False, TextSize=3, OtsuScaling=0.25)
# Finished in about 4min (236.7 sec)
# Out:
# Enumerating image 1/127:  ./Images/PGR_GH2021\B2p0363T4.tif
# Image B2p0363T4.tif, 1/127, was enumerated in 3.0 seconds.
#
# Enumerating image 2/127:  ./Images/PGR_GH2021\B2p0371T3.tif
# Image B2p0371T3.tif, 2/127, was enumerated in 3.1 seconds.
#
# Enumerating image 3/127:  ./Images/PGR_GH2021\B2p0391T1.tif
# Image B2p0391T1.tif, 3/127, was enumerated in 3.1 seconds.
#
# Enumerating image 4/127:  ./Images/PGR_GH2021\B2p0393T6.tif
# Image B2p0393T6.tif, 4/127, was enumerated in 3.2 seconds.
#
# Enumerating image 5/127:  ./Images/PGR_GH2021\B2p0401T9.tif
# Image B2p0401T9.tif, 5/127, was enumerated in 3.2 seconds.
#
# Enumerating image 6/127:  ./Images/PGR_GH2021\B2p0407T9.tif
# Image B2p0407T9.tif, 6/127, was enumerated in 3.3 seconds.
#
# Enumerating image 7/127:  ./Images/PGR_GH2021\B2p0421T3.tif
# Image B2p0421T3.tif, 7/127, was enumerated in 3.3 seconds.
#
# Enumerating image 8/127:  ./Images/PGR_GH2021\B2p0423T2.tif
# Image B2p0423T2.tif, 8/127, was enumerated in 3.7 seconds.
#
# Enumerating image 9/127:  ./Images/PGR_GH2021\B2p0435T8.tif
# Image B2p0435T8.tif, 9/127, was enumerated in 3.4 seconds.
#
# Enumerating image 10/127:  ./Images/PGR_GH2021\B2p0441T7.tif
# Image B2p0441T7.tif, 10/127, was enumerated in 3.3 seconds.
#
# Enumerating image 11/127:  ./Images/PGR_GH2021\B2p0445T1.tif
# Image B2p0445T1.tif, 11/127, was enumerated in 3.2 seconds.
#
# Enumerating image 12/127:  ./Images/PGR_GH2021\B2p0449T7.tif
# Image B2p0449T7.tif, 12/127, was enumerated in 3.2 seconds.
#
# Enumerating image 13/127:  ./Images/PGR_GH2021\B2p0457T6.tif
# Image B2p0457T6.tif, 13/127, was enumerated in 3.3 seconds.
#
# Enumerating image 14/127:  ./Images/PGR_GH2021\B2p0489T3.tif
# Image B2p0489T3.tif, 14/127, was enumerated in 3.4 seconds.
#
# Enumerating image 15/127:  ./Images/PGR_GH2021\B2p0509T4.tif
# Image B2p0509T4.tif, 15/127, was enumerated in 3.2 seconds.
#
# Enumerating image 16/127:  ./Images/PGR_GH2021\B2p0517T1.tif
# Image B2p0517T1.tif, 16/127, was enumerated in 3.1 seconds.
#
# Enumerating image 17/127:  ./Images/PGR_GH2021\B2p0519T9.tif
# Image B2p0519T9.tif, 17/127, was enumerated in 3.1 seconds.
#
# Enumerating image 18/127:  ./Images/PGR_GH2021\B2p0523T9.tif
# Image B2p0523T9.tif, 18/127, was enumerated in 3.1 seconds.
#
# Enumerating image 19/127:  ./Images/PGR_GH2021\B2p0533T2.tif
# Image B2p0533T2.tif, 19/127, was enumerated in 3.5 seconds.
#
# Enumerating image 20/127:  ./Images/PGR_GH2021\B2p0553T9.tif
# Image B2p0553T9.tif, 20/127, was enumerated in 3.2 seconds.
#
# Enumerating image 21/127:  ./Images/PGR_GH2021\B2p0555T7.tif
# Image B2p0555T7.tif, 21/127, was enumerated in 3.1 seconds.
#
# Enumerating image 22/127:  ./Images/PGR_GH2021\B2p0565T6.tif
# Image B2p0565T6.tif, 22/127, was enumerated in 3.1 seconds.
#
# Enumerating image 23/127:  ./Images/PGR_GH2021\B2p0569T4.tif
# Image B2p0569T4.tif, 23/127, was enumerated in 3.2 seconds.
#
# Enumerating image 24/127:  ./Images/PGR_GH2021\B2p0581T2.tif
# Image B2p0581T2.tif, 24/127, was enumerated in 3.3 seconds.
#
# Enumerating image 25/127:  ./Images/PGR_GH2021\B2p0595T9.tif
# Image B2p0595T9.tif, 25/127, was enumerated in 3.5 seconds.
#
# Enumerating image 26/127:  ./Images/PGR_GH2021\B2p0597T4.tif
# Image B2p0597T4.tif, 26/127, was enumerated in 3.3 seconds.
#
# Enumerating image 27/127:  ./Images/PGR_GH2021\B2p0599T3.tif
# Image B2p0599T3.tif, 27/127, was enumerated in 3.4 seconds.
#
# Enumerating image 28/127:  ./Images/PGR_GH2021\B2p0601T7.tif
# Image B2p0601T7.tif, 28/127, was enumerated in 3.6 seconds.
#
# Enumerating image 29/127:  ./Images/PGR_GH2021\B2p0613T2.tif
# Image B2p0613T2.tif, 29/127, was enumerated in 3.6 seconds.
#
# Enumerating image 30/127:  ./Images/PGR_GH2021\B2p0615T1.tif
# Image B2p0615T1.tif, 30/127, was enumerated in 3.3 seconds.
#
# Enumerating image 31/127:  ./Images/PGR_GH2021\B2p0621T6.tif
# Image B2p0621T6.tif, 31/127, was enumerated in 3.2 seconds.
#
# Enumerating image 32/127:  ./Images/PGR_GH2021\B2p0629T8.tif
# Image B2p0629T8.tif, 32/127, was enumerated in 3.3 seconds.
#
# Enumerating image 33/127:  ./Images/PGR_GH2021\B2p0633T2.tif
# Image B2p0633T2.tif, 33/127, was enumerated in 3.2 seconds.
#
# Enumerating image 34/127:  ./Images/PGR_GH2021\B2p0643T1.tif
# Image B2p0643T1.tif, 34/127, was enumerated in 3.5 seconds.
#
# Enumerating image 35/127:  ./Images/PGR_GH2021\B2p0645T8.tif
# Image B2p0645T8.tif, 35/127, was enumerated in 3.7 seconds.
#
# Enumerating image 36/127:  ./Images/PGR_GH2021\B2p0647T1.tif
# Image B2p0647T1.tif, 36/127, was enumerated in 3.8 seconds.
#
# Enumerating image 37/127:  ./Images/PGR_GH2021\B2p0649T4.tif
# Image B2p0649T4.tif, 37/127, was enumerated in 3.9 seconds.
#
# Enumerating image 38/127:  ./Images/PGR_GH2021\B2p0655T1.tif
# Image B2p0655T1.tif, 38/127, was enumerated in 3.4 seconds.
#
# Enumerating image 39/127:  ./Images/PGR_GH2021\B2p0669T7.tif
# Image B2p0669T7.tif, 39/127, was enumerated in 3.7 seconds.
#
# Enumerating image 40/127:  ./Images/PGR_GH2021\B2p0673T7.tif
# Image B2p0673T7.tif, 40/127, was enumerated in 3.7 seconds.
#
# Enumerating image 41/127:  ./Images/PGR_GH2021\B2p0675T4.tif
# Image B2p0675T4.tif, 41/127, was enumerated in 4.0 seconds.
#
# Enumerating image 42/127:  ./Images/PGR_GH2021\B2p0677T5.tif
# Image B2p0677T5.tif, 42/127, was enumerated in 3.8 seconds.
#
# Enumerating image 43/127:  ./Images/PGR_GH2021\B2p0683T3.tif
# Image B2p0683T3.tif, 43/127, was enumerated in 3.9 seconds.
#
# Enumerating image 44/127:  ./Images/PGR_GH2021\B2p0685T3.tif
# Image B2p0685T3.tif, 44/127, was enumerated in 4.3 seconds.
#
# Enumerating image 45/127:  ./Images/PGR_GH2021\B2p0687T6.tif
# Image B2p0687T6.tif, 45/127, was enumerated in 4.1 seconds.
#
# Enumerating image 46/127:  ./Images/PGR_GH2021\B2p0689T2.tif
# Image B2p0689T2.tif, 46/127, was enumerated in 3.7 seconds.
#
# Enumerating image 47/127:  ./Images/PGR_GH2021\B2p0699T1.tif
# Image B2p0699T1.tif, 47/127, was enumerated in 4.0 seconds.
#
# Enumerating image 48/127:  ./Images/PGR_GH2021\B2p0701T2.tif
# Image B2p0701T2.tif, 48/127, was enumerated in 4.2 seconds.
#
# Enumerating image 49/127:  ./Images/PGR_GH2021\B2p0703T3.tif
# Image B2p0703T3.tif, 49/127, was enumerated in 3.9 seconds.
#
# Enumerating image 50/127:  ./Images/PGR_GH2021\B2p0705T9.tif
# Image B2p0705T9.tif, 50/127, was enumerated in 3.8 seconds.
#
# Enumerating image 51/127:  ./Images/PGR_GH2021\B2p0713T9.tif
# Image B2p0713T9.tif, 51/127, was enumerated in 3.9 seconds.
#
# Enumerating image 52/127:  ./Images/PGR_GH2021\B2p0715T7.tif
# Image B2p0715T7.tif, 52/127, was enumerated in 3.4 seconds.
#
# Enumerating image 53/127:  ./Images/PGR_GH2021\B2p0717T9.tif
# Image B2p0717T9.tif, 53/127, was enumerated in 3.4 seconds.
#
# Enumerating image 54/127:  ./Images/PGR_GH2021\B2p0719T5.tif
# Image B2p0719T5.tif, 54/127, was enumerated in 3.3 seconds.
#
# Enumerating image 55/127:  ./Images/PGR_GH2021\B3p0725T3.tif
# Image B3p0725T3.tif, 55/127, was enumerated in 3.4 seconds.
#
# Enumerating image 56/127:  ./Images/PGR_GH2021\B3p0727T3.tif
# Image B3p0727T3.tif, 56/127, was enumerated in 3.4 seconds.
#
# Enumerating image 57/127:  ./Images/PGR_GH2021\B3p0729T8.tif
# Image B3p0729T8.tif, 57/127, was enumerated in 3.2 seconds.
#
# Enumerating image 58/127:  ./Images/PGR_GH2021\B3p0737T7.tif
# Image B3p0737T7.tif, 58/127, was enumerated in 3.2 seconds.
#
# Enumerating image 59/127:  ./Images/PGR_GH2021\B3p0741T8.tif
# Image B3p0741T8.tif, 59/127, was enumerated in 3.3 seconds.
#
# Enumerating image 60/127:  ./Images/PGR_GH2021\B3p0743T4.tif
# Image B3p0743T4.tif, 60/127, was enumerated in 3.4 seconds.
#
# Enumerating image 61/127:  ./Images/PGR_GH2021\B3p0751T3.tif
# Image B3p0751T3.tif, 61/127, was enumerated in 3.3 seconds.
#
# Enumerating image 62/127:  ./Images/PGR_GH2021\B3p0753T9.tif
# Image B3p0753T9.tif, 62/127, was enumerated in 3.1 seconds.
#
# Enumerating image 63/127:  ./Images/PGR_GH2021\B3p0755T6.tif
# Image B3p0755T6.tif, 63/127, was enumerated in 3.0 seconds.
#
# Enumerating image 64/127:  ./Images/PGR_GH2021\B3p0757T7.tif
# Image B3p0757T7.tif, 64/127, was enumerated in 3.1 seconds.
#
# Enumerating image 65/127:  ./Images/PGR_GH2021\B3p0759T6.tif
# Image B3p0759T6.tif, 65/127, was enumerated in 3.2 seconds.
#
# Enumerating image 66/127:  ./Images/PGR_GH2021\B3p0767T6.tif
# Image B3p0767T6.tif, 66/127, was enumerated in 3.2 seconds.
#
# Enumerating image 67/127:  ./Images/PGR_GH2021\B3p0769T9.tif
# Image B3p0769T9.tif, 67/127, was enumerated in 3.2 seconds.
#
# Enumerating image 68/127:  ./Images/PGR_GH2021\B3p0771T4.tif
# Image B3p0771T4.tif, 68/127, was enumerated in 3.4 seconds.
#
# Enumerating image 69/127:  ./Images/PGR_GH2021\B3p0773T2.tif
# Image B3p0773T2.tif, 69/127, was enumerated in 3.1 seconds.
#
# Enumerating image 70/127:  ./Images/PGR_GH2021\B3p0775T7.tif
# Image B3p0775T7.tif, 70/127, was enumerated in 3.1 seconds.
#
# Enumerating image 71/127:  ./Images/PGR_GH2021\B3p0781T2.tif
# Image B3p0781T2.tif, 71/127, was enumerated in 3.4 seconds.
#
# Enumerating image 72/127:  ./Images/PGR_GH2021\B3p0787T1.tif
# Image B3p0787T1.tif, 72/127, was enumerated in 3.2 seconds.
#
# Enumerating image 73/127:  ./Images/PGR_GH2021\B3p0795T8.tif
# Image B3p0795T8.tif, 73/127, was enumerated in 3.3 seconds.
#
# Enumerating image 74/127:  ./Images/PGR_GH2021\B3p0799T1.tif
# Image B3p0799T1.tif, 74/127, was enumerated in 3.3 seconds.
#
# Enumerating image 75/127:  ./Images/PGR_GH2021\B3p0805T8.tif
# Image B3p0805T8.tif, 75/127, was enumerated in 3.4 seconds.
#
# Enumerating image 76/127:  ./Images/PGR_GH2021\B3p0817T3.tif
# Image B3p0817T3.tif, 76/127, was enumerated in 3.4 seconds.
#
# Enumerating image 77/127:  ./Images/PGR_GH2021\B3p0819T4.tif
# Image B3p0819T4.tif, 77/127, was enumerated in 3.8 seconds.
#
# Enumerating image 78/127:  ./Images/PGR_GH2021\B3p0823T7.tif
# Image B3p0823T7.tif, 78/127, was enumerated in 3.7 seconds.
#
# Enumerating image 79/127:  ./Images/PGR_GH2021\B3p0833T6.tif
# Image B3p0833T6.tif, 79/127, was enumerated in 3.6 seconds.
#
# Enumerating image 80/127:  ./Images/PGR_GH2021\B3p0853T3.tif
# Image B3p0853T3.tif, 80/127, was enumerated in 3.7 seconds.
#
# Enumerating image 81/127:  ./Images/PGR_GH2021\B3p0855T8.tif
# Image B3p0855T8.tif, 81/127, was enumerated in 3.5 seconds.
#
# Enumerating image 82/127:  ./Images/PGR_GH2021\B3p0863T7.tif
# Image B3p0863T7.tif, 82/127, was enumerated in 3.5 seconds.
#
# Enumerating image 83/127:  ./Images/PGR_GH2021\B3p0871T4.tif
# Image B3p0871T4.tif, 83/127, was enumerated in 3.4 seconds.
#
# Enumerating image 84/127:  ./Images/PGR_GH2021\B3p0879T8.tif
# Image B3p0879T8.tif, 84/127, was enumerated in 3.7 seconds.
#
# Enumerating image 85/127:  ./Images/PGR_GH2021\B3p0883T6.tif
# Image B3p0883T6.tif, 85/127, was enumerated in 3.4 seconds.
#
# Enumerating image 86/127:  ./Images/PGR_GH2021\B3p0893T9.tif
# Image B3p0893T9.tif, 86/127, was enumerated in 3.3 seconds.
#
# Enumerating image 87/127:  ./Images/PGR_GH2021\B3p0903T2.tif
# Image B3p0903T2.tif, 87/127, was enumerated in 3.5 seconds.
#
# Enumerating image 88/127:  ./Images/PGR_GH2021\B3p0915T8.tif
# Image B3p0915T8.tif, 88/127, was enumerated in 3.4 seconds.
#
# Enumerating image 89/127:  ./Images/PGR_GH2021\B3p0921T3.tif
# Image B3p0921T3.tif, 89/127, was enumerated in 3.2 seconds.
#
# Enumerating image 90/127:  ./Images/PGR_GH2021\B3p0925T1.tif
# Image B3p0925T1.tif, 90/127, was enumerated in 3.2 seconds.
#
# Enumerating image 91/127:  ./Images/PGR_GH2021\B3p0927T7.tif
# Image B3p0927T7.tif, 91/127, was enumerated in 3.3 seconds.
#
# Enumerating image 92/127:  ./Images/PGR_GH2021\B3p0933T3.tif
# Image B3p0933T3.tif, 92/127, was enumerated in 3.7 seconds.
#
# Enumerating image 93/127:  ./Images/PGR_GH2021\B3p0935T7.tif
# Image B3p0935T7.tif, 93/127, was enumerated in 3.4 seconds.
#
# Enumerating image 94/127:  ./Images/PGR_GH2021\B3p0941T6.tif
# Image B3p0941T6.tif, 94/127, was enumerated in 4.0 seconds.
#
# Enumerating image 95/127:  ./Images/PGR_GH2021\B3p0947T9.tif
# Image B3p0947T9.tif, 95/127, was enumerated in 3.3 seconds.
#
# Enumerating image 96/127:  ./Images/PGR_GH2021\B3p0949T4.tif
# Image B3p0949T4.tif, 96/127, was enumerated in 3.1 seconds.
#
# Enumerating image 97/127:  ./Images/PGR_GH2021\B3p0951T6.tif
# Image B3p0951T6.tif, 97/127, was enumerated in 3.5 seconds.
#
# Enumerating image 98/127:  ./Images/PGR_GH2021\B3p0955T9.tif
# Image B3p0955T9.tif, 98/127, was enumerated in 3.3 seconds.
#
# Enumerating image 99/127:  ./Images/PGR_GH2021\B3p0961T4.tif
# Image B3p0961T4.tif, 99/127, was enumerated in 3.7 seconds.
#
# Enumerating image 100/127:  ./Images/PGR_GH2021\B3p0985T8.tif
# Image B3p0985T8.tif, 100/127, was enumerated in 3.1 seconds.
#
# Enumerating image 101/127:  ./Images/PGR_GH2021\B3p0987T2.tif
# Image B3p0987T2.tif, 101/127, was enumerated in 3.2 seconds.
#
# Enumerating image 102/127:  ./Images/PGR_GH2021\B3p0991T9.tif
# Image B3p0991T9.tif, 102/127, was enumerated in 3.7 seconds.
#
# Enumerating image 103/127:  ./Images/PGR_GH2021\B3p0993T2.tif
# Image B3p0993T2.tif, 103/127, was enumerated in 3.9 seconds.
#
# Enumerating image 104/127:  ./Images/PGR_GH2021\B3p0995T7.tif
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\AppData\Local\Temp/ipykernel_19484/3647789230.py in EnumBatch(Images, TROE2020, TextSize, OtsuScaling)
#      18
#      19         # Remove background and create images
# ---> 20         I = RemoveBackground(img_name, OtsuScaling=OtsuScaling, rgb_out=True, gray_out=False, lab_out=False, hsv_out=False, bw_out=True)
#      21         rgb0 = I[0]
#      22         bw0 = I[1]
#
# ~\Google Drive\M.Sc\THESIS\ImageAnalysis\SpikeProperties\SpykProps\SpykFunctions.py in RemoveBackground(img, OtsuScaling, rgb_out, gray_out, lab_out, hsv_out, bw_out)
#      83     # Read image
#      84     if isinstance(img, str) == True:
# ---> 85         img0 = io.imread(img)
#      86     else:
#      87         img0 = img
#
# J:\My Drive\M.Sc\THESIS\ImageAnalysis\SpikeProperties\envspk\lib\site-packages\skimage\io\_io.py in imread(fname, as_gray, plugin, **plugin_args)
#      46
#      47     with file_or_url_context(fname) as fname:
# ---> 48         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      49
#      50     if not hasattr(img, 'ndim'):
#
# J:\My Drive\M.Sc\THESIS\ImageAnalysis\SpikeProperties\envspk\lib\site-packages\skimage\io\manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     205                                (plugin, kind))
#     206
# --> 207     return func(*args, **kwargs)
#     208
#     209
#
# J:\My Drive\M.Sc\THESIS\ImageAnalysis\SpikeProperties\envspk\lib\site-packages\skimage\io\_plugins\tifffile_plugin.py in imread(fname, **kwargs)
#      28         kwargs['key'] = kwargs.pop('img_num')
#      29
# ---> 30     return tifffile_imread(fname, **kwargs)
#
# J:\My Drive\M.Sc\THESIS\ImageAnalysis\SpikeProperties\envspk\lib\site-packages\tifffile\tifffile.py in imread(files, aszarr, **kwargs)
#     859                 if aszarr:
#     860                     return tif.aszarr(**kwargs)
# --> 861                 return tif.asarray(**kwargs)
#     862
#     863     with TiffSequence(files, **kwargs_seq) as imseq:
#
# J:\My Drive\M.Sc\THESIS\ImageAnalysis\SpikeProperties\envspk\lib\site-packages\tifffile\tifffile.py in asarray(self, key, series, level, squeeze, out, maxworkers)
#    3282                 )
#    3283         elif len(pages) == 1:
# -> 3284             result = pages[0].asarray(out=out, maxworkers=maxworkers)
#    3285         else:
#    3286             result = stack_pages(pages, out=out, maxworkers=maxworkers)
#
# J:\My Drive\M.Sc\THESIS\ImageAnalysis\SpikeProperties\envspk\lib\site-packages\tifffile\tifffile.py in asarray(self, out, squeeze, lock, maxworkers)
#    6675                 #     pass  # corrupted files e.g. with too many strips
#    6676
# -> 6677             for _ in self.segments(
#    6678                 func=func,
#    6679                 lock=lock,
#
# J:\My Drive\M.Sc\THESIS\ImageAnalysis\SpikeProperties\envspk\lib\site-packages\tifffile\tifffile.py in segments(self, lock, maxworkers, func, sort, _fullsize)
#    6539                     flat=False,
#    6540                 ):
# -> 6541                     yield from executor.map(decode, segments)
#    6542
#    6543     def asarray(self, out=None, squeeze=True, lock=None, maxworkers=None):
#
# ~\AppData\Local\Programs\Python\Python38\lib\concurrent\futures\_base.py in result_iterator()
#     609                     # Careful not to keep a reference to the popped future
#     610                     if timeout is None:
# --> 611                         yield fs.pop().result()
#     612                     else:
#     613                         yield fs.pop().result(end_time - time.monotonic())
#
# ~\AppData\Local\Programs\Python\Python38\lib\concurrent\futures\_base.py in result(self, timeout)
#     430                 raise CancelledError()
#     431             elif self._state == FINISHED:
# --> 432                 return self.__get_result()
#     433
#     434             self._condition.wait(timeout)
#
# ~\AppData\Local\Programs\Python\Python38\lib\concurrent\futures\_base.py in __get_result(self)
#     386     def __get_result(self):
#     387         if self._exception:
# --> 388             raise self._exception
#     389         else:
#     390             return self._result
#
# ~\AppData\Local\Programs\Python\Python38\lib\concurrent\futures\thread.py in run(self)
#      55
#      56         try:
# ---> 57             result = self.fn(*self.args, **self.kwargs)
#      58         except BaseException as exc:
#      59             self.future.set_exception(exc)
#
# J:\My Drive\M.Sc\THESIS\ImageAnalysis\SpikeProperties\envspk\lib\site-packages\tifffile\tifffile.py in decode(args, decodeargs, keyframe, func)
#    6514                 args, decodeargs=decodeargs, keyframe=keyframe, func=func
#    6515             ):
# -> 6516                 return func(keyframe.decode(*args, **decodeargs))
#    6517
#    6518         if maxworkers is None or maxworkers < 1:
#
# J:\My Drive\M.Sc\THESIS\ImageAnalysis\SpikeProperties\envspk\lib\site-packages\tifffile\tifffile.py in decode(exc, *args, **kwargs)
#    6130
#    6131             def decode(*args, exc=str(exc)[1:-1], **kwargs):
# -> 6132                 raise ValueError(f'TiffPage {self.index}: {exc}')
#    6133
#    6134             return cache(decode)
#
# ValueError: TiffPage 0: <COMPRESSION.LZW: 5> requires the 'imagecodecs' package

# %% [markdown]
# # Gifs
# Gifs for presentations

# %%
# pip install imutils

# %%
from SpykFunctions import *
path = r'./Images/PGR_Roseau2021'
Images = ListImages(path, imgformat=".tif", recursive=False)
# img = Images['S1p14T4R3.tif']
img = [s for s in Images if "S1p15T5R3" in s]
img = img[0]

# %% [markdown]
# ## Remove Background

# %%
# %%time

# Remove Backgrouns
OtsuScaling=0.25
rgb_out=True
gray_out=True
lab_out=True
hsv_out=True

img0 = plt.imread(img)


# Crop images. They were all taken with the same scanner
img1 = img0[44:6940, 25:4970, :]

plt.imsave('.\GIFS\CSSA\Spikes\\01_RGBoriginal.jpg',img1)

 # Convert to gray
gray0 = img1 @ [0.2126, 0.7152, 0.0722]

plt.imsave('.\GIFS\CSSA\Spikes\\02_GRAYoriginal.jpg',gray0, cmap='gray')

# Set image threshold
T = filters.threshold_otsu(gray0)
#     print(T)
T = T*OtsuScaling
#     print(T)

# Segment gray image
bw0 = gray0 > T

plt.imsave('.\GIFS\CSSA\Spikes\\03_BWoriginal.jpg', bw0, cmap='gray')

# Remove small objects
n_pixels = gray0.shape[0] * gray0.shape[1]
minimum_size = n_pixels/10000
bw1 = morphology.remove_small_objects(bw0, min_size=np.floor(minimum_size))

plt.imsave('.\GIFS\CSSA\Spikes\\04_BW1original.jpg', bw1, cmap='gray')


if rgb_out==True:
    # Apply mask to RGB
    rgb = np.where(bw1[..., None], img1, 0)
    plt.imsave('.\GIFS\CSSA\Spikes\\05_ThreshRGB.jpg', rgb)
if gray_out==True and rgb_out==True:
    gray = color.rgb2gray(rgb)
    plt.imsave('.\GIFS\CSSA\Spikes\\06_ThreshGRAY.jpg', gray, cmap='gray')
# if lab_out==True and rgb_out==True:
    # lab = color.rgb2lab(rgb)
    # plt.imsave('.\GIFS\CSSA\Spikes\\07_ThreshLAB.jpg', lab)
if hsv_out==True and rgb_out==True:
    hsv = color.rgb2hsv(rgb)
    plt.imsave('.\GIFS\CSSA\Spikes\\08_ThreshHSV.jpg', hsv)

# %% [markdown]
# ## Enumerate

# %%
# %%time

TextSize = 5
nb_components, output, stats, centroids = cv2.connectedComponentsWithStats(np.uint8(bw1), connectivity=8)
img = rgb.copy()

counter=0
for c in centroids:
#         print(c)
    cx = round(c[0])
    cy = round(c[1])
    img = cv2.circle(img, (cx, cy), 10, (255, 0, 0), -1)
    img = cv2.putText(img, str(counter), (cx - 25, cy - 25),cv2.FONT_HERSHEY_SIMPLEX, TextSize, (255, 0, 0), 15)
    counter = counter+1

    if len(str(counter)) < 2:
        thisContour = '0' + str(counter)
    else:
        thisContour = str(counter)
    plotname = '.\GIFS\CSSA\Spikes\\09_enumerate_' + thisContour + '.jpg'
    plt.imsave(plotname, img)
    # plt.imshow(img)

# %%
# %%time
# EnumPlot = EnumerateSpkCV(bw1, rgb, TextSize=5, TROE2020=False, Plot=False, PlotOut=True)
# plotname = '.\GIFS\CSSA\Spikes\\10_enumerate_' + thisContour + '.jpg'
# plt.imsave(plotname, img)

# %% [markdown]
# ## Select a spike

# %%
# %%time

# Label spikes
labeled_spks, num_spikes = label(bw1, return_num = True)
# plt.imshow(labeled_spks==1)

Label = 8

spk = labeled_spks==Label
# plt.imshow(spk, cmap='gray')
plotname = '.\GIFS\CSSA\Spikes\\10_SelectedSpike_' + str(Label) + '.jpg'
plt.imsave(plotname, spk, cmap='gray')

# Crop spike
slice_x, slice_y = ndimage.find_objects(spk)[0]
cropped_spk = spk[slice_x, slice_y]
cropped_rgb = rgb[slice_x, slice_y]
cropped_rgb = np.where(cropped_spk[..., None], cropped_rgb, 0)
cropped_gray = color.rgb2gray(cropped_rgb)
cropped_lab = color.rgb2lab(cropped_rgb)
cropped_hsv = color.rgb2hsv(cropped_rgb)

plotname = '.\GIFS\CSSA\Spike\\01_rgb.jpg'
plt.imsave(plotname, cropped_rgb)
plotname = '.\GIFS\CSSA\Spike\\02_gray.jpg'
plt.imsave(plotname, cropped_gray, cmap='gray')
# plotname = '.\GIFS\CSSA\Spike\\03_lab.jpg'
# plt.imsave(plotname, cropped_lab)
plotname = '.\GIFS\CSSA\Spike\\04_hsv.jpg'
plt.imsave(plotname, cropped_hsv)
plotname = '.\GIFS\CSSA\Spike\\05_bw.jpg'
plt.imsave(plotname, cropped_spk, cmap='gray')

# %% [markdown]
# ## Spike Length

# %%
# %%time
def spk_length(cropped_spk, method='skelblur', Overlay=True, PlotCH=False, PlotOut=False):
    
    if method=='skelblur':
        # Severly blur the image
        blur = cv2.blur(np.float32(cropped_spk),(100,100))
        # Threshold the blur
        thrb = blur > 0.1
        skeleton = skeletonize(thrb)
#         plt.imshow(skeleton)
        
    if method=='chull':
        # Blur the image with a 50x50 kernel
        blur = cv2.blur(np.float32(cropped_spk),(50,50))

        # Get convex hull 
        chull = convex_hull_image(blur>0)

        # Perform skeletonization
        image = chull
        skeleton = skeletonize(image)
    #     plt.imshow(skeleton)
    
    # Spike length
    SpkL = cv2.countNonZero(np.float32(skeleton))
    
    if PlotCH == True:
        fig, axes = plt.subplots(1, 2, figsize=(8, 4))
        ax = axes.ravel()

        ax[0].set_title('Original picture')
        ax[0].imshow(cropped_spk, cmap=plt.cm.gray)
        ax[0].set_axis_off()

        ax[1].set_title('Transformed picture')
        ax[1].imshow(chull, cmap=plt.cm.gray)
        ax[1].set_axis_off()

        plt.tight_layout()
        plt.show()
    
    # Visualize overlay?
    if Overlay == True:
        overlay_images = cv2.addWeighted(np.float32(cropped_spk),20,np.float32(skeleton),255,0)
        plt.imshow(overlay_images, cmap='gray')
    
    if PlotOut==True:
        overlay_images = cv2.addWeighted(np.float32(cropped_spk),20,np.float32(skeleton),255,0)
        return SpkL, overlay_images
    else:
        return SpkL

# Example:
SL, SLplot = spk_length(cropped_spk, method='skelblur', Overlay=False, PlotCH=False, PlotOut=True)
plt.imshow(SLplot, cmap='gray')
# SL = spk_length(cropped_spk, method='skelblur', Overlay=True, PlotCH=False)

# %%
# %%time

plotname = '.\GIFS\CSSA\Spike\spk_length\\06_bw.jpg'
plt.imsave(plotname, cropped_spk, cmap='gray')

# Severly blur the image
blur = cv2.blur(np.float32(cropped_spk),(100,100))
plotname = '.\GIFS\CSSA\Spike\spk_length\\07_bw_blur.jpg'
plt.imsave(plotname, blur, cmap='gray')

# Threshold the blur
thrb = blur > 0.1
plotname = '.\GIFS\CSSA\Spike\spk_length\\08_bw_thrb.jpg'
plt.imsave(plotname, thrb, cmap='gray')

# Create skeleton
skeleton = skeletonize(thrb)
plotname = '.\GIFS\CSSA\Spike\spk_length\\09_bw_skel.jpg'
plt.imsave(plotname, skeleton, cmap='gray')

# Overlay skeleton
overlay_images = cv2.addWeighted(np.float32(cropped_spk),20,np.float32(skeleton),255,0)
plotname = '.\GIFS\CSSA\Spike\spk_length\\10_bw_SkelOverlay.jpg'
plt.imsave(plotname, overlay_images, cmap='gray')

# %% [markdown]
# ## Treshold for contrours

# %%
# %%time

ResizeFactor=30
thr2=0.8
MinSize=1000

plotname = '.\GIFS\CSSA\Spike\\thresh2\\11_bw.jpg'
plt.imsave(plotname, cropped_spk, cmap='gray')

# Reduce image size
im = Image.fromarray((cropped_gray*255).astype(np.uint8))
(width, height) = (im.width // ResizeFactor, im.height // ResizeFactor)
rescaled_spk = im.resize((width, height))
plotname = '.\GIFS\CSSA\Spike\\thresh2\\12_bw_resized.jpg'
plt.imsave(plotname, np.asarray(rescaled_spk), cmap='gray')


# Increase to original size
(width, height) = (im.width, im.height)
rescaled_spk = rescaled_spk.resize((width, height))
rescaled_spk = np.asarray(rescaled_spk)
plotname = '.\GIFS\CSSA\Spike\\thresh2\\13_bw_SizeRestored.jpg'
plt.imsave(plotname, rescaled_spk, cmap='gray')

# Histogram equalization
rescaled_spk = exposure.equalize_hist(rescaled_spk)
plotname = '.\GIFS\CSSA\Spike\\thresh2\\14_bw_HistEq.jpg'
plt.imsave(plotname, rescaled_spk, cmap='gray')

# Blur with a Gaussian
blurred = filters.gaussian(rescaled_spk, sigma=1, preserve_range=True)
plotname = '.\GIFS\CSSA\Spike\\thresh2\\15_bw_GaussBlur.jpg'
plt.imsave(plotname, blurred, cmap='gray')

# Adaptative equalization
blurred = exposure.equalize_adapthist(blurred)
plotname = '.\GIFS\CSSA\Spike\\thresh2\\16_bw_AdaptHist.jpg'
plt.imsave(plotname, blurred, cmap='gray')

# Normalize
blurred = cv2.normalize(blurred, None, alpha = 0, beta = 255, norm_type = cv2.NORM_MINMAX, dtype = cv2.CV_32F)
blurred = blurred.astype(np.uint8)

if thr2 < 1 == True:
    thr2 = thr2*255
else:
    thr2 = thr2

# Threshold at given %
ret, thresh = cv2.threshold(blurred, thr2, 255, 0)
thresh = np.uint8(thresh)
plotname = '.\GIFS\CSSA\Spike\\thresh2\\17_bw_thresh.jpg'
plt.imsave(plotname, thresh, cmap='gray')

nb_components, output, stats, centroids = cv2.connectedComponentsWithStats(thresh, connectivity=8)
sizes = stats[1:, -1]; nb_components = nb_components - 1    

thresh2 = np.zeros((output.shape))

# Keep only objects with minimum size
for i in range(0, nb_components):
    if sizes[i] >= MinSize:
        thresh2[output == i + 1] = 255

#     plt.imshow(thresh2)
thresh2 = np.uint8(thresh2)
plotname = '.\GIFS\CSSA\Spike\\thresh2\\18_bw_thresh2.jpg'
plt.imsave(plotname, thresh2, cmap='gray')

# %% [markdown]
# ## Watershed

# %%
# %%time

plotname = '.\GIFS\CSSA\Spike\Watershed\\01_rgb.jpg'
plt.imsave(plotname, cropped_rgb)

# Rescale to 10% of original
rescaled_spk = rescale(cropped_rgb[...], 0.1, preserve_range=False, multichannel=True, anti_aliasing=True)
# plt.imshow(rescaled_spk)
plotname = '.\GIFS\CSSA\Spike\Watershed\\02_rescaled.jpg'
plt.imsave(plotname, rescaled_spk)


# Erosion
kernel = cv2.getStructuringElement(cv2.MORPH_CROSS,(3,3))
erosion = cv2.erode(rescaled_spk,kernel,iterations = 1)
# plt.imshow(erosion)
plotname = '.\GIFS\CSSA\Spike\Watershed\\03_erosion.jpg'
plt.imsave(plotname, erosion)

# Opening
kernel = np.ones((1,1),np.uint8)
opening = cv2.morphologyEx(erosion, cv2.MORPH_OPEN, kernel, iterations = 10)
# plt.imshow(opening)
plotname = '.\GIFS\CSSA\Spike\Watershed\\04_opening.jpg'
plt.imsave(plotname, opening)

# Resize
rescaled_spk2 = Image.fromarray((rescaled_spk * 255).astype(np.uint8))
rescaled_spk2 = rescaled_spk2.resize((cropped_rgb.shape[1],cropped_rgb.shape[0]))
# plt.imshow(rescaled_spk2)
# rescaled_spk2.size
opening = np.asarray(rescaled_spk2)
# plt.imshow(opening)
plotname = '.\GIFS\CSSA\Spike\Watershed\\05_ResizedOpening.jpg'
plt.imsave(plotname, opening)


# Convert rgb to gray
gray_spklts = opening @ [0.2126, 0.7152, 0.0722]
# plt.imshow(gray_spklts)
plotname = '.\GIFS\CSSA\Spike\Watershed\\06_gray.jpg'
plt.imsave(plotname, gray_spklts, cmap='gray')

# Binarize gray
bw_spklts = gray_spklts > 0
# plt.imshow(bw_spklts)
plotname = '.\GIFS\CSSA\Spike\Watershed\\07_binary.jpg'
plt.imsave(plotname, bw_spklts, cmap='gray')

# Get distances
distance = ndi.distance_transform_edt(bw_spklts)
# plt.imshow(-distance)
plotname = '.\GIFS\CSSA\Spike\Watershed\\08_distance.jpg'
plt.imsave(plotname, distance, cmap='gray')

MinDist=50
# Get max peaks
coords = peak_local_max(distance, min_distance=MinDist, labels=bw_spklts)
# plt.imshow(coords)
plotname = '.\GIFS\CSSA\Spike\Watershed\\09_coords.jpg'
plt.imsave(plotname, coords, cmap='gray')

mask = np.zeros(distance.shape, dtype=bool)
mask[tuple(coords.T)] = True
markers, spikelets = ndi.label(mask)
plotname = '.\GIFS\CSSA\Spike\Watershed\\10_markers.jpg'
plt.imsave(plotname, markers, cmap='gray')

# Watershed
labels = watershed(-distance, markers, mask=bw_spklts)
#     plt.imshow(labels)
plotname = '.\GIFS\CSSA\Spike\Watershed\\11_labels.jpg'
plt.imsave(plotname, labels)

labels2 = np.unique(labels[labels > 0])

C = []

for label in labels2:
        y = labels == label
        y = y * 255
        y = y.astype('uint8')
        contours, hierarchy = cv2.findContours(y, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        # len(contours)
        contours = np.squeeze(contours)
        C.append(contours)

#         plt.imshow(d[2])

contours = C

OutImage = cropped_rgb.copy()

# Plot all found contours
OutImage = cv2.drawContours(OutImage, contours, -1, (0,0,0), 10);
# plt.imshow(OutImage)

count = 11

for c in contours:
    try:

        # Generate random colors
        random_channels = (np.random.choice(range(256), size=3))
        rr = int(random_channels[0])
        rg = int(random_channels[1])
        rb = int(random_channels[2])

        ellipse = cv2.fitEllipse(c)
        OutImage = cv2.ellipse(OutImage,ellipse,(rr,rg,rb),10);

        count = count+1
        plotname = '.\GIFS\CSSA\Spike\Watershed\\' + str(count) + '_contour.jpg'
        plt.imsave(plotname, OutImage)

        # Fit a line 
        rows,cols = OutImage.shape[:2]
        [vx,vy,x,y] = cv2.fitLine(c, cv2.DIST_L2,0,0.01,0.01);
        lefty = int((-x*vy/vx) + y)
        righty = int(((cols-x)*vy/vx)+y)
        # OutImage = cv2.line(OutImage,(cols-1,righty),(0,lefty),(rr,rg,rb),3);

        # Slope from tope left, which is is the origin [0,0]
        rise = (0,lefty)[1] - (cols-1,righty)[1]
        run = cols
        Slope = rise/run
        Slopes.append(Slope) 
    except:
        pass

# %%
LabelSpklts(cropped_rgb, MinDist=50, labels_out=False, n_spklt=False, ElliPlot=False, Plot=True)

# %% [markdown]
# ## Distances all

# %% [markdown]
# ## Contours

# %%
# Contours
labels_cont = CountorProps(cropped_rgb, cropped_lab, cropped_hsv, thresh2, ImagePath=img_name, ResizeFactor=30, MinSize = 1000, thr2=0.8, plot=False)
